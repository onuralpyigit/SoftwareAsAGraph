# %%
# Install required packages.
import os
import torch
os.environ['TORCH'] = torch.__version__
print(torch.__version__)

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q git+https://github.com/pyg-team/pytorch_geometric.git

# Helper function for visualization.
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

def visualize(h, color):
    z = TSNE(n_components=2).fit_transform(h.detach().cpu().numpy())

    plt.figure(figsize=(10,10))
    plt.xticks([])
    plt.yticks([])

    plt.scatter(z[:, 0], z[:, 1], s=70, c=color, cmap="Set2")
    plt.show()
# Out:
# 2.0.0+cu117
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.1
# [notice] To update, run: python -m pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.1
# [notice] To update, run: python -m pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.1
# [notice] To update, run: python -m pip install --upgrade pip

# %%
# Load the graph data from a file
import pickle

project_name = "jfreechart"
#project_name = "argouml"
output_graph_data_file = "output/" + project_name + "/graph_data_for_problematic_classes.pickle"
with open(output_graph_data_file, 'rb') as file:
    G = pickle.load(file)

# Print nodes with their embedding
for node, embedding in G.nodes(data=True):
    print(f"Node: {node}, embedding: {embedding}")
# Out:
# Node: org.jfree.chart.entity.EntityCollection, embedding: {'CBO': 1.0, 'RFC': 8.0, 'SRFC': 0.0, 'DIT': 1.0, 'NOC': 1.0, 'WMC': 8.0, 'LOC': 9.0, 'CMLOC': 8.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 8.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.7, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.statistics.DefaultStatisticalCategoryDataset, embedding: {'CBO': 4.0, 'RFC': 90.0, 'SRFC': 37.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 86.0, 'LOC': 280.0, 'CMLOC': 264.0, 'NOF': 13.0, 'NOSF': 0.0, 'NOM': 30.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.818, 'LCAM': 0.754, 'LTCC': 0.367, 'ATFD': 1.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.gantt.Task, embedding: {'CBO': 3.0, 'RFC': 25.0, 'SRFC': 10.0, 'DIT': 1.0, 'NOC': 0.0, 'WMC': 22.0, 'LOC': 66.0, 'CMLOC': 60.0, 'NOF': 4.0, 'NOSF': 1.0, 'NOM': 16.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.717, 'LCAM': 0.806, 'LTCC': 0.65, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.event.ChartProgress, embedding: {'CBO': 3.0, 'RFC': 8.0, 'SRFC': 1.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 7.0, 'LOC': 24.0, 'CMLOC': 20.0, 'NOF': 3.0, 'NOSF': 0.0, 'NOM': 7.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.667, 'LCAM': 0.6, 'LTCC': 0.571, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.util.DirectionalGradientPaintTransformer, embedding: {'CBO': 0.0, 'RFC': 14.0, 'SRFC': 12.0, 'DIT': 1.0, 'NOC': 0.0, 'WMC': 12.0, 'LOC': 37.0, 'CMLOC': 36.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 2.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.333, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.statistics.BoxAndWhiskerXYDataset, embedding: {'CBO': 0.0, 'RFC': 11.0, 'SRFC': 0.0, 'DIT': 1.0, 'NOC': 1.0, 'WMC': 11.0, 'LOC': 13.0, 'CMLOC': 11.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 11.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.091, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.entity.StandardEntityCollection, embedding: {'CBO': 2.0, 'RFC': 27.0, 'SRFC': 15.0, 'DIT': 1.0, 'NOC': 0.0, 'WMC': 17.0, 'LOC': 58.0, 'CMLOC': 54.0, 'NOF': 1.0, 'NOSF': 1.0, 'NOM': 12.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.545, 'LCAM': 0.764, 'LTCC': 0.0, 'ATFD': 1.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.entity., embedding: {'CBO': 4.0, 'RFC': 103.0, 'SRFC': 15.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 16.0, 'LOC': 52.0, 'CMLOC': 49.0, 'NOF': 1.0, 'NOSF': 1.0, 'NOM': 10.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.75, 'LCAM': 0.7, 'LTCC': 0.893, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.util.ExportUtils, embedding: {'CBO': 2.0, 'RFC': 17.0, 'SRFC': 13.0, 'DIT': 1.0, 'NOC': 0.0, 'WMC': 13.0, 'LOC': 79.0, 'CMLOC': 78.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 0.0, 'NOSM': 6.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.25, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.UnknownKeyException, embedding: {'CBO': 0.0, 'RFC': 1.0, 'SRFC': 0.0, 'DIT': 5.0, 'NOC': 0.0, 'WMC': 1.0, 'LOC': 3.0, 'CMLOC': 2.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 1.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.plot.pie.PiePlot, embedding: {'CBO': 37.0, 'RFC': 483.0, 'SRFC': 191.0, 'DIT': 2.0, 'NOC': 1.0, 'WMC': 302.0, 'LOC': 1220.0, 'CMLOC': 1151.0, 'NOF': 48.0, 'NOSF': 15.0, 'NOM': 132.0, 'NOSM': 0.0, 'NORM': 1.0, 'LCOM': 0.961, 'LCAM': 0.941, 'LTCC': 0.934, 'ATFD': 3.0, 'SI': 0.015, 'Problematic': 2}
# Node: org.jfree.chart.renderer.WaferMapRenderer, embedding: {'CBO': 5.0, 'RFC': 58.0, 'SRFC': 34.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 44.0, 'LOC': 143.0, 'CMLOC': 135.0, 'NOF': 4.0, 'NOSF': 3.0, 'NOM': 15.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.757, 'LCAM': 0.711, 'LTCC': 0.929, 'ATFD': 2.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.xy.XIntervalDataItem, embedding: {'CBO': 1.0, 'RFC': 10.0, 'SRFC': 5.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 8.0, 'LOC': 23.0, 'CMLOC': 22.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 5.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.4, 'LTCC': 0.0, 'ATFD': 1.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.legend., embedding: {'CBO': 11.0, 'RFC': 210.0, 'SRFC': 47.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 76.0, 'LOC': 240.0, 'CMLOC': 223.0, 'NOF': 14.0, 'NOSF': 1.0, 'NOM': 38.0, 'NOSM': 0.0, 'NORM': 1.0, 'LCOM': 0.85, 'LCAM': 0.868, 'LTCC': 0.792, 'ATFD': 2.0, 'SI': 0.053, 'Problematic': 1}
# Node: org.jfree.chart.text.TextFragment, embedding: {'CBO': 5.0, 'RFC': 84.0, 'SRFC': 24.0, 'DIT': 1.0, 'NOC': 0.0, 'WMC': 28.0, 'LOC': 85.0, 'CMLOC': 77.0, 'NOF': 4.0, 'NOSF': 3.0, 'NOM': 15.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.791, 'LCAM': 0.788, 'LTCC': 0.577, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.labels.CategoryToolTipGenerator, embedding: {'CBO': 1.0, 'RFC': 1.0, 'SRFC': 0.0, 'DIT': 1.0, 'NOC': 2.0, 'WMC': 1.0, 'LOC': 2.0, 'CMLOC': 1.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 1.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.plot.SeriesRenderingOrder, embedding: {'CBO': 0.0, 'RFC': 0.0, 'SRFC': 0.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 0.0, 'LOC': 3.0, 'CMLOC': 0.0, 'NOF': 0.0, 'NOSF': 2.0, 'NOM': 0.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.statistics.DefaultMultiValueCategoryDataset, embedding: {'CBO': 3.0, 'RFC': 64.0, 'SRFC': 26.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 44.0, 'LOC': 141.0, 'CMLOC': 134.0, 'NOF': 4.0, 'NOSF': 0.0, 'NOM': 20.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.711, 'LCAM': 0.781, 'LTCC': 0.253, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.general.KeyedValuesDataset, embedding: {'CBO': 0.0, 'RFC': 0.0, 'SRFC': 0.0, 'DIT': 1.0, 'NOC': 1.0, 'WMC': 0.0, 'LOC': 2.0, 'CMLOC': 0.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 0.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.xy.DefaultIntervalXYDataset, embedding: {'CBO': 4.0, 'RFC': 40.0, 'SRFC': 20.0, 'DIT': 5.0, 'NOC': 0.0, 'WMC': 38.0, 'LOC': 154.0, 'CMLOC': 149.0, 'NOF': 2.0, 'NOSF': 0.0, 'NOM': 20.0, 'NOSM': 0.0, 'NORM': 6.0, 'LCOM': 0.346, 'LCAM': 0.63, 'LTCC': 0.563, 'ATFD': 0.0, 'SI': 1.5, 'Problematic': 0}
# Node: org.jfree.chart.annotations.XYPointerAnnotation, embedding: {'CBO': 12.0, 'RFC': 182.0, 'SRFC': 48.0, 'DIT': 4.0, 'NOC': 0.0, 'WMC': 38.0, 'LOC': 187.0, 'CMLOC': 171.0, 'NOF': 8.0, 'NOSF': 6.0, 'NOM': 23.0, 'NOSM': 0.0, 'NORM': 1.0, 'LCOM': 0.854, 'LCAM': 0.87, 'LTCC': 0.629, 'ATFD': 2.0, 'SI': 0.174, 'Problematic': 1}
# Node: org.jfree.chart.plot.dial.AbstractDial, embedding: {'CBO': 3.0, 'RFC': 20.0, 'SRFC': 10.0, 'DIT': 1.0, 'NOC': 9.0, 'WMC': 15.0, 'LOC': 50.0, 'CMLOC': 47.0, 'NOF': 2.0, 'NOSF': 0.0, 'NOM': 11.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.5, 'LCAM': 0.766, 'LTCC': 0.571, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.time.Week, embedding: {'CBO': 3.0, 'RFC': 50.0, 'SRFC': 29.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 62.0, 'LOC': 226.0, 'CMLOC': 218.0, 'NOF': 4.0, 'NOSF': 3.0, 'NOM': 21.0, 'NOSM': 4.0, 'NORM': 0.0, 'LCOM': 0.737, 'LCAM': 0.809, 'LTCC': 0.481, 'ATFD': 1.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.util.GradientPaintTransformer, embedding: {'CBO': 0.0, 'RFC': 1.0, 'SRFC': 0.0, 'DIT': 1.0, 'NOC': 2.0, 'WMC': 1.0, 'LOC': 2.0, 'CMLOC': 1.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 1.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.block.BlockBorder, embedding: {'CBO': 4.0, 'RFC': 66.0, 'SRFC': 18.0, 'DIT': 1.0, 'NOC': 0.0, 'WMC': 19.0, 'LOC': 68.0, 'CMLOC': 62.0, 'NOF': 2.0, 'NOSF': 2.0, 'NOM': 11.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.75, 'LCAM': 0.778, 'LTCC': 0.75, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.plot.dial.Dial, embedding: {'CBO': 8.0, 'RFC': 68.0, 'SRFC': 13.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 18.0, 'LOC': 64.0, 'CMLOC': 59.0, 'NOF': 2.0, 'NOSF': 1.0, 'NOM': 13.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.593, 'LCAM': 0.812, 'LTCC': 0.564, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.axis.CategoryTick, embedding: {'CBO': 3.0, 'RFC': 11.0, 'SRFC': 4.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 12.0, 'LOC': 38.0, 'CMLOC': 34.0, 'NOF': 3.0, 'NOSF': 0.0, 'NOM': 6.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.4, 'LCAM': 0.714, 'LTCC': 0.2, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.annotations.XYPolygonAnnotation, embedding: {'CBO': 10.0, 'RFC': 96.0, 'SRFC': 30.0, 'DIT': 3.0, 'NOC': 0.0, 'WMC': 30.0, 'LOC': 116.0, 'CMLOC': 109.0, 'NOF': 4.0, 'NOSF': 1.0, 'NOM': 13.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.533, 'LCAM': 0.828, 'LTCC': 0.6, 'ATFD': 1.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.plot.compass.PointerNeedle, embedding: {'CBO': 0.0, 'RFC': 65.0, 'SRFC': 25.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 12.0, 'LOC': 52.0, 'CMLOC': 49.0, 'NOF': 0.0, 'NOSF': 1.0, 'NOM': 4.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.625, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.plot.CategoryCrosshairState, embedding: {'CBO': 3.0, 'RFC': 15.0, 'SRFC': 8.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 13.0, 'LOC': 47.0, 'CMLOC': 43.0, 'NOF': 2.0, 'NOSF': 0.0, 'NOM': 7.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.333, 'LCAM': 0.548, 'LTCC': 0.19, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.plot.CategoryMarker, embedding: {'CBO': 3.0, 'RFC': 45.0, 'SRFC': 5.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 15.0, 'LOC': 44.0, 'CMLOC': 41.0, 'NOF': 2.0, 'NOSF': 0.0, 'NOM': 9.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.417, 'LCAM': 0.683, 'LTCC': 0.583, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.time.TimePeriodFormatException, embedding: {'CBO': 0.0, 'RFC': 1.0, 'SRFC': 0.0, 'DIT': 5.0, 'NOC': 0.0, 'WMC': 1.0, 'LOC': 3.0, 'CMLOC': 2.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 1.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.encoders.ImageEncoderFactory, embedding: {'CBO': 1.0, 'RFC': 14.0, 'SRFC': 9.0, 'DIT': 1.0, 'NOC': 0.0, 'WMC': 9.0, 'LOC': 39.0, 'CMLOC': 35.0, 'NOF': 0.0, 'NOSF': 1.0, 'NOM': 0.0, 'NOSM': 6.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.375, 'LTCC': 0.9, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.swing.editor.DefaultPolarPlotEditor, embedding: {'CBO': 5.0, 'RFC': 103.0, 'SRFC': 26.0, 'DIT': 6.0, 'NOC': 0.0, 'WMC': 17.0, 'LOC': 79.0, 'CMLOC': 73.0, 'NOF': 4.0, 'NOSF': 0.0, 'NOM': 9.0, 'NOSM': 0.0, 'NORM': 1.0, 'LCOM': 0.5, 'LCAM': 0.667, 'LTCC': 0.619, 'ATFD': 2.0, 'SI': 0.667, 'Problematic': 0}
# Node: org.jfree.chart.renderer.xy.WindItemRenderer, embedding: {'CBO': 9.0, 'RFC': 57.0, 'SRFC': 19.0, 'DIT': 3.0, 'NOC': 0.0, 'WMC': 3.0, 'LOC': 63.0, 'CMLOC': 60.0, 'NOF': 0.0, 'NOSF': 1.0, 'NOM': 3.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.6, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.labels.SymbolicXYItem, embedding: {'CBO': 7.0, 'RFC': 27.0, 'SRFC': 13.0, 'DIT': 1.0, 'NOC': 0.0, 'WMC': 12.0, 'LOC': 46.0, 'CMLOC': 43.0, 'NOF': 0.0, 'NOSF': 1.0, 'NOM': 5.0, 'NOSM': 1.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.567, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.xy.YIntervalSeries, embedding: {'CBO': 2.0, 'RFC': 35.0, 'SRFC': 8.0, 'DIT': 3.0, 'NOC': 0.0, 'WMC': 9.0, 'LOC': 25.0, 'CMLOC': 24.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 9.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.63, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.axis.CompassFormat, embedding: {'CBO': 1.0, 'RFC': 10.0, 'SRFC': 4.0, 'DIT': 3.0, 'NOC': 0.0, 'WMC': 9.0, 'LOC': 33.0, 'CMLOC': 31.0, 'NOF': 1.0, 'NOSF': 0.0, 'NOM': 7.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.633, 'LTCC': 0.952, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.axis.DateTickMarkPosition, embedding: {'CBO': 0.0, 'RFC': 0.0, 'SRFC': 0.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 0.0, 'LOC': 4.0, 'CMLOC': 0.0, 'NOF': 0.0, 'NOSF': 3.0, 'NOM': 0.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.xml.CategorySeriesHandler, embedding: {'CBO': 6.0, 'RFC': 37.0, 'SRFC': 10.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 9.0, 'LOC': 40.0, 'CMLOC': 35.0, 'NOF': 3.0, 'NOSF': 0.0, 'NOM': 5.0, 'NOSM': 0.0, 'NORM': 2.0, 'LCOM': 0.583, 'LCAM': 0.6, 'LTCC': 0.4, 'ATFD': 1.0, 'SI': 0.8, 'Problematic': 0}
# Node: org.jfree.chart.ChartTheme, embedding: {'CBO': 1.0, 'RFC': 1.0, 'SRFC': 0.0, 'DIT': 1.0, 'NOC': 1.0, 'WMC': 1.0, 'LOC': 2.0, 'CMLOC': 1.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 1.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.text.TextMeasurer, embedding: {'CBO': 0.0, 'RFC': 1.0, 'SRFC': 0.0, 'DIT': 1.0, 'NOC': 1.0, 'WMC': 1.0, 'LOC': 2.0, 'CMLOC': 1.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 1.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.general.SeriesChange, embedding: {'CBO': 0.0, 'RFC': 1.0, 'SRFC': 0.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 1.0, 'LOC': 4.0, 'CMLOC': 2.0, 'NOF': 0.0, 'NOSF': 1.0, 'NOM': 1.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.renderer.xy.StandardXYItemRenderer, embedding: {'CBO': 21.0, 'RFC': 308.0, 'SRFC': 82.0, 'DIT': 3.0, 'NOC': 1.0, 'WMC': 100.0, 'LOC': 329.0, 'CMLOC': 296.0, 'NOF': 10.0, 'NOSF': 7.0, 'NOM': 34.0, 'NOSM': 0.0, 'NORM': 2.0, 'LCOM': 0.92, 'LCAM': 0.896, 'LTCC': 0.821, 'ATFD': 3.0, 'SI': 0.176, 'Problematic': 2}
# Node: org.jfree.chart.annotations.XYShapeAnnotation, embedding: {'CBO': 10.0, 'RFC': 126.0, 'SRFC': 33.0, 'DIT': 3.0, 'NOC': 0.0, 'WMC': 22.0, 'LOC': 105.0, 'CMLOC': 98.0, 'NOF': 4.0, 'NOSF': 1.0, 'NOM': 9.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.24, 'LCAM': 0.786, 'LTCC': 0.714, 'ATFD': 1.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.swing.OverlayChangeEvent, embedding: {'CBO': 0.0, 'RFC': 1.0, 'SRFC': 0.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 1.0, 'LOC': 3.0, 'CMLOC': 2.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 1.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.renderer.AbstractRenderer, embedding: {'CBO': 16.0, 'RFC': 306.0, 'SRFC': 100.0, 'DIT': 1.0, 'NOC': 4.0, 'WMC': 316.0, 'LOC': 908.0, 'CMLOC': 848.0, 'NOF': 46.0, 'NOSF': 11.0, 'NOM': 159.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.965, 'LCAM': 0.897, 'LTCC': 0.969, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 2}
# Node: org.jfree.chart.event.MarkerChange, embedding: {'CBO': 1.0, 'RFC': 2.0, 'SRFC': 0.0, 'DIT': 3.0, 'NOC': 0.0, 'WMC': 2.0, 'LOC': 7.0, 'CMLOC': 5.0, 'NOF': 1.0, 'NOSF': 0.0, 'NOM': 2.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.25, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.labels.MultipleXYSeries, embedding: {'CBO': 3.0, 'RFC': 28.0, 'SRFC': 18.0, 'DIT': 1.0, 'NOC': 0.0, 'WMC': 19.0, 'LOC': 81.0, 'CMLOC': 74.0, 'NOF': 3.0, 'NOSF': 2.0, 'NOM': 9.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.686, 'LCAM': 0.6, 'LTCC': 0.25, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.imagemap.UR, embedding: {'CBO': 0.0, 'RFC': 1.0, 'SRFC': 0.0, 'DIT': 1.0, 'NOC': 1.0, 'WMC': 1.0, 'LOC': 2.0, 'CMLOC': 1.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 1.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.swing.editor.DefaultNumberAxisEditor, embedding: {'CBO': 4.0, 'RFC': 97.0, 'SRFC': 28.0, 'DIT': 7.0, 'NOC': 0.0, 'WMC': 13.0, 'LOC': 67.0, 'CMLOC': 63.0, 'NOF': 2.0, 'NOSF': 0.0, 'NOM': 7.0, 'NOSM': 0.0, 'NORM': 1.0, 'LCOM': 0.3, 'LCAM': 0.686, 'LTCC': 0.467, 'ATFD': 2.0, 'SI': 1.0, 'Problematic': 0}
# Node: org.jfree.chart.renderer.category.CategoryStepRenderer, embedding: {'CBO': 11.0, 'RFC': 210.0, 'SRFC': 45.0, 'DIT': 3.0, 'NOC': 0.0, 'WMC': 29.0, 'LOC': 124.0, 'CMLOC': 114.0, 'NOF': 1.0, 'NOSF': 2.0, 'NOM': 9.0, 'NOSM': 0.0, 'NORM': 2.0, 'LCOM': 0.833, 'LCAM': 0.807, 'LTCC': 0.714, 'ATFD': 1.0, 'SI': 0.667, 'Problematic': 1}
# Node: org.jfree.chart.plot.XYPlot, embedding: {'CBO': 41.0, 'RFC': 648.0, 'SRFC': 323.0, 'DIT': 2.0, 'NOC': 2.0, 'WMC': 679.0, 'LOC': 2042.0, 'CMLOC': 1969.0, 'NOF': 56.0, 'NOSF': 7.0, 'NOM': 236.0, 'NOSM': 0.0, 'NORM': 6.0, 'LCOM': 0.968, 'LCAM': 0.936, 'LTCC': 0.968, 'ATFD': 10.0, 'SI': 0.051, 'Problematic': 2}
# Node: org.jfree.chart.renderer.xy.XYSplineRenderer, embedding: {'CBO': 12.0, 'RFC': 117.0, 'SRFC': 33.0, 'DIT': 4.0, 'NOC': 0.0, 'WMC': 48.0, 'LOC': 196.0, 'CMLOC': 180.0, 'NOF': 3.0, 'NOSF': 0.0, 'NOM': 13.0, 'NOSM': 0.0, 'NORM': 2.0, 'LCOM': 0.5, 'LCAM': 0.799, 'LTCC': 0.709, 'ATFD': 1.0, 'SI': 0.615, 'Problematic': 0}
# Node: org.jfree.data.category.DefaultCategoryDataset, embedding: {'CBO': 1.0, 'RFC': 91.0, 'SRFC': 38.0, 'DIT': 2.0, 'NOC': 1.0, 'WMC': 35.0, 'LOC': 102.0, 'CMLOC': 97.0, 'NOF': 1.0, 'NOSF': 1.0, 'NOM': 25.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.525, 'LCAM': 0.691, 'LTCC': 0.3, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.xy.YisSymbolic, embedding: {'CBO': 0.0, 'RFC': 3.0, 'SRFC': 0.0, 'DIT': 1.0, 'NOC': 0.0, 'WMC': 3.0, 'LOC': 4.0, 'CMLOC': 3.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 3.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.444, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.renderer.xy.XYBoxAndWhiskerRenderer, embedding: {'CBO': 20.0, 'RFC': 234.0, 'SRFC': 74.0, 'DIT': 3.0, 'NOC': 0.0, 'WMC': 69.0, 'LOC': 325.0, 'CMLOC': 318.0, 'NOF': 4.0, 'NOSF': 1.0, 'NOM': 23.0, 'NOSM': 0.0, 'NORM': 1.0, 'LCOM': 0.754, 'LCAM': 0.826, 'LTCC': 0.767, 'ATFD': 5.0, 'SI': 0.13, 'Problematic': 1}
# Node: org.jfree.chart.renderer.category.AreaRenderer, embedding: {'CBO': 13.0, 'RFC': 250.0, 'SRFC': 56.0, 'DIT': 3.0, 'NOC': 1.0, 'WMC': 31.0, 'LOC': 141.0, 'CMLOC': 137.0, 'NOF': 1.0, 'NOSF': 1.0, 'NOM': 7.0, 'NOSM': 0.0, 'NORM': 1.0, 'LCOM': 0.625, 'LCAM': 0.766, 'LTCC': 0.524, 'ATFD': 2.0, 'SI': 0.429, 'Problematic': 1}
# Node: org.jfree.data.function., embedding: {'CBO': 0.0, 'RFC': 1.0, 'SRFC': 0.0, 'DIT': 1.0, 'NOC': 4.0, 'WMC': 1.0, 'LOC': 2.0, 'CMLOC': 1.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 1.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.event.ChartChangeEvent, embedding: {'CBO': 3.0, 'RFC': 8.0, 'SRFC': 1.0, 'DIT': 2.0, 'NOC': 7.0, 'WMC': 7.0, 'LOC': 22.0, 'CMLOC': 19.0, 'NOF': 2.0, 'NOSF': 0.0, 'NOM': 7.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.5, 'LCAM': 0.464, 'LTCC': 0.714, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.function.PolynomialFunction2D, embedding: {'CBO': 2.0, 'RFC': 11.0, 'SRFC': 4.0, 'DIT': 1.0, 'NOC': 0.0, 'WMC': 8.0, 'LOC': 24.0, 'CMLOC': 22.0, 'NOF': 1.0, 'NOSF': 0.0, 'NOM': 6.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.5, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.renderer.xy.XYBarRenderer, embedding: {'CBO': 25.0, 'RFC': 352.0, 'SRFC': 100.0, 'DIT': 3.0, 'NOC': 2.0, 'WMC': 133.0, 'LOC': 455.0, 'CMLOC': 429.0, 'NOF': 13.0, 'NOSF': 3.0, 'NOM': 40.0, 'NOSM': 4.0, 'NORM': 4.0, 'LCOM': 0.918, 'LCAM': 0.906, 'LTCC': 0.869, 'ATFD': 4.0, 'SI': 0.3, 'Problematic': 2}
# Node: org.jfree.data.category.CategoryDataset, embedding: {'CBO': 0.0, 'RFC': 0.0, 'SRFC': 0.0, 'DIT': 1.0, 'NOC': 7.0, 'WMC': 0.0, 'LOC': 2.0, 'CMLOC': 0.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 0.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.RangeType, embedding: {'CBO': 0.0, 'RFC': 0.0, 'SRFC': 0.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 0.0, 'LOC': 4.0, 'CMLOC': 0.0, 'NOF': 0.0, 'NOSF': 3.0, 'NOM': 0.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.time.ohlc.OH, embedding: {'CBO': 1.0, 'RFC': 9.0, 'SRFC': 1.0, 'DIT': 1.0, 'NOC': 0.0, 'WMC': 13.0, 'LOC': 42.0, 'CMLOC': 37.0, 'NOF': 4.0, 'NOSF': 0.0, 'NOM': 7.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.5, 'LCAM': 0.571, 'LTCC': 0.286, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.event.TitleChangeEvent, embedding: {'CBO': 1.0, 'RFC': 2.0, 'SRFC': 0.0, 'DIT': 3.0, 'NOC': 0.0, 'WMC': 2.0, 'LOC': 7.0, 'CMLOC': 5.0, 'NOF': 1.0, 'NOSF': 0.0, 'NOM': 2.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.25, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.plot.pie.MultiplePiePlot, embedding: {'CBO': 23.0, 'RFC': 355.0, 'SRFC': 70.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 63.0, 'LOC': 248.0, 'CMLOC': 238.0, 'NOF': 8.0, 'NOSF': 1.0, 'NOM': 24.0, 'NOSM': 0.0, 'NORM': 1.0, 'LCOM': 0.783, 'LCAM': 0.896, 'LTCC': 0.69, 'ATFD': 3.0, 'SI': 0.083, 'Problematic': 1}
# Node: org.jfree.chart.event.TitleChange, embedding: {'CBO': 1.0, 'RFC': 2.0, 'SRFC': 0.0, 'DIT': 3.0, 'NOC': 0.0, 'WMC': 2.0, 'LOC': 7.0, 'CMLOC': 5.0, 'NOF': 1.0, 'NOSF': 0.0, 'NOM': 2.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.25, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.statistics.Regression, embedding: {'CBO': 2.0, 'RFC': 15.0, 'SRFC': 10.0, 'DIT': 1.0, 'NOC': 0.0, 'WMC': 37.0, 'LOC': 183.0, 'CMLOC': 182.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 0.0, 'NOSM': 6.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.375, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.general.Dataset, embedding: {'CBO': 1.0, 'RFC': 2.0, 'SRFC': 0.0, 'DIT': 1.0, 'NOC': 7.0, 'WMC': 2.0, 'LOC': 3.0, 'CMLOC': 2.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 2.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.xy.XYCoordinate, embedding: {'CBO': 0.0, 'RFC': 9.0, 'SRFC': 1.0, 'DIT': 1.0, 'NOC': 0.0, 'WMC': 17.0, 'LOC': 50.0, 'CMLOC': 47.0, 'NOF': 2.0, 'NOSF': 0.0, 'NOM': 8.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.167, 'LCAM': 0.542, 'LTCC': 0.286, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.xy.XYDomainInfo, embedding: {'CBO': 1.0, 'RFC': 1.0, 'SRFC': 0.0, 'DIT': 1.0, 'NOC': 1.0, 'WMC': 1.0, 'LOC': 2.0, 'CMLOC': 1.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 1.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.statistics.DefaultBoxAndWhiskerCategoryDataset, embedding: {'CBO': 4.0, 'RFC': 116.0, 'SRFC': 43.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 90.0, 'LOC': 319.0, 'CMLOC': 309.0, 'NOF': 7.0, 'NOSF': 0.0, 'NOM': 45.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.801, 'LCAM': 0.733, 'LTCC': 0.248, 'ATFD': 1.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.category.CategoryRangeInfo, embedding: {'CBO': 1.0, 'RFC': 1.0, 'SRFC': 0.0, 'DIT': 1.0, 'NOC': 0.0, 'WMC': 1.0, 'LOC': 3.0, 'CMLOC': 1.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 1.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.general.AbstractDataset, embedding: {'CBO': 2.0, 'RFC': 22.0, 'SRFC': 12.0, 'DIT': 1.0, 'NOC': 14.0, 'WMC': 16.0, 'LOC': 47.0, 'CMLOC': 42.0, 'NOF': 2.0, 'NOSF': 1.0, 'NOM': 12.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.704, 'LCAM': 0.774, 'LTCC': 0.667, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.time.TimePeriodValue, embedding: {'CBO': 2.0, 'RFC': 14.0, 'SRFC': 7.0, 'DIT': 1.0, 'NOC': 0.0, 'WMC': 18.0, 'LOC': 47.0, 'CMLOC': 43.0, 'NOF': 2.0, 'NOSF': 1.0, 'NOM': 9.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.6, 'LCAM': 0.667, 'LTCC': 0.639, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.plot.CombinedRangeXYPlot, embedding: {'CBO': 18.0, 'RFC': 523.0, 'SRFC': 85.0, 'DIT': 3.0, 'NOC': 0.0, 'WMC': 80.0, 'LOC': 264.0, 'CMLOC': 258.0, 'NOF': 3.0, 'NOSF': 1.0, 'NOM': 29.0, 'NOSM': 0.0, 'NORM': 12.0, 'LCOM': 0.75, 'LCAM': 0.87, 'LTCC': 0.604, 'ATFD': 3.0, 'SI': 1.241, 'Problematic': 1}
# Node: org.jfree.data.xy.MatrixSeriesCollection, embedding: {'CBO': 4.0, 'RFC': 53.0, 'SRFC': 22.0, 'DIT': 5.0, 'NOC': 0.0, 'WMC': 23.0, 'LOC': 77.0, 'CMLOC': 72.0, 'NOF': 1.0, 'NOSF': 1.0, 'NOM': 16.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.542, 'LCAM': 0.578, 'LTCC': 0.35, 'ATFD': 1.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.ComparableObjectItem, embedding: {'CBO': 1.0, 'RFC': 13.0, 'SRFC': 6.0, 'DIT': 1.0, 'NOC': 5.0, 'WMC': 13.0, 'LOC': 39.0, 'CMLOC': 34.0, 'NOF': 2.0, 'NOSF': 1.0, 'NOM': 8.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.611, 'LCAM': 0.594, 'LTCC': 0.4, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.axis.Category, embedding: {'CBO': 0.0, 'RFC': 0.0, 'SRFC': 0.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 0.0, 'LOC': 4.0, 'CMLOC': 0.0, 'NOF': 0.0, 'NOSF': 3.0, 'NOM': 0.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.labels.Flow, embedding: {'CBO': 2.0, 'RFC': 1.0, 'SRFC': 0.0, 'DIT': 1.0, 'NOC': 1.0, 'WMC': 1.0, 'LOC': 2.0, 'CMLOC': 1.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 1.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.annotations.CategoryAnnotation, embedding: {'CBO': 3.0, 'RFC': 1.0, 'SRFC': 0.0, 'DIT': 1.0, 'NOC': 2.0, 'WMC': 1.0, 'LOC': 3.0, 'CMLOC': 1.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 1.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.entity.ChartEntity, embedding: {'CBO': 5.0, 'RFC': 77.0, 'SRFC': 26.0, 'DIT': 1.0, 'NOC': 12.0, 'WMC': 38.0, 'LOC': 126.0, 'CMLOC': 121.0, 'NOF': 3.0, 'NOSF': 1.0, 'NOM': 20.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.696, 'LCAM': 0.806, 'LTCC': 0.633, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.api.PublicCloneable, embedding: {'CBO': 0.0, 'RFC': 1.0, 'SRFC': 0.0, 'DIT': 1.0, 'NOC': 139.0, 'WMC': 1.0, 'LOC': 2.0, 'CMLOC': 1.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 1.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.statistics.BoxAndWhiskerCategoryDataset, embedding: {'CBO': 0.0, 'RFC': 18.0, 'SRFC': 0.0, 'DIT': 1.0, 'NOC': 1.0, 'WMC': 18.0, 'LOC': 20.0, 'CMLOC': 18.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 18.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.375, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.time.DynamicTimeSeriesCollection, embedding: {'CBO': 5.0, 'RFC': 58.0, 'SRFC': 24.0, 'DIT': 5.0, 'NOC': 0.0, 'WMC': 89.0, 'LOC': 302.0, 'CMLOC': 266.0, 'NOF': 19.0, 'NOSF': 3.0, 'NOM': 42.0, 'NOSM': 0.0, 'NORM': 1.0, 'LCOM': 0.923, 'LCAM': 0.721, 'LTCC': 0.825, 'ATFD': 0.0, 'SI': 0.119, 'Problematic': 0}
# Node: org.jfree.chart.text.Text, embedding: {'CBO': 0.0, 'RFC': 8.0, 'SRFC': 0.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 8.0, 'LOC': 41.0, 'CMLOC': 25.0, 'NOF': 0.0, 'NOSF': 15.0, 'NOM': 8.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.857, 'LCAM': 0.0, 'LTCC': 0.464, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.api.RectangleAnchor, embedding: {'CBO': 2.0, 'RFC': 12.0, 'SRFC': 10.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 20.0, 'LOC': 85.0, 'CMLOC': 75.0, 'NOF': 0.0, 'NOSF': 9.0, 'NOM': 1.0, 'NOSM': 1.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.4, 'LTCC': 0.0, 'ATFD': 1.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.urls.XYUR, embedding: {'CBO': 1.0, 'RFC': 1.0, 'SRFC': 0.0, 'DIT': 1.0, 'NOC': 4.0, 'WMC': 1.0, 'LOC': 2.0, 'CMLOC': 1.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 1.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.labels.Item, embedding: {'CBO': 0.0, 'RFC': 0.0, 'SRFC': 0.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 0.0, 'LOC': 26.0, 'CMLOC': 0.0, 'NOF': 0.0, 'NOSF': 25.0, 'NOM': 0.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.renderer.category.DefaultCategoryItemRenderer, embedding: {'CBO': 0.0, 'RFC': 0.0, 'SRFC': 0.0, 'DIT': 4.0, 'NOC': 0.0, 'WMC': 0.0, 'LOC': 3.0, 'CMLOC': 0.0, 'NOF': 0.0, 'NOSF': 1.0, 'NOM': 0.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.swing.SelectionZoomStrategy, embedding: {'CBO': 0.0, 'RFC': 15.0, 'SRFC': 0.0, 'DIT': 1.0, 'NOC': 1.0, 'WMC': 15.0, 'LOC': 16.0, 'CMLOC': 15.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 15.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.775, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.renderer.category.BoxAndWhiskerRenderer, embedding: {'CBO': 20.0, 'RFC': 274.0, 'SRFC': 105.0, 'DIT': 3.0, 'NOC': 0.0, 'WMC': 115.0, 'LOC': 460.0, 'CMLOC': 447.0, 'NOF': 10.0, 'NOSF': 1.0, 'NOM': 34.0, 'NOSM': 0.0, 'NORM': 1.0, 'LCOM': 0.844, 'LCAM': 0.848, 'LTCC': 0.788, 'ATFD': 6.0, 'SI': 0.088, 'Problematic': 1}
# Node: org.jfree.data.xy.AbstractXYDataset, embedding: {'CBO': 1.0, 'RFC': 6.0, 'SRFC': 3.0, 'DIT': 3.0, 'NOC': 10.0, 'WMC': 5.0, 'LOC': 19.0, 'CMLOC': 17.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 3.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.167, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.statistics.MultiValueCategoryDataset, embedding: {'CBO': 0.0, 'RFC': 2.0, 'SRFC': 0.0, 'DIT': 1.0, 'NOC': 1.0, 'WMC': 2.0, 'LOC': 4.0, 'CMLOC': 2.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 2.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.375, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.time.Year, embedding: {'CBO': 1.0, 'RFC': 34.0, 'SRFC': 14.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 29.0, 'LOC': 101.0, 'CMLOC': 94.0, 'NOF': 3.0, 'NOSF': 3.0, 'NOM': 18.0, 'NOSM': 1.0, 'NORM': 0.0, 'LCOM': 0.833, 'LCAM': 0.789, 'LTCC': 0.532, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.date.SerialDate, embedding: {'CBO': 1.0, 'RFC': 59.0, 'SRFC': 30.0, 'DIT': 1.0, 'NOC': 1.0, 'WMC': 119.0, 'LOC': 279.0, 'CMLOC': 239.0, 'NOF': 1.0, 'NOSF': 30.0, 'NOM': 22.0, 'NOSM': 25.0, 'NORM': 0.0, 'LCOM': 0.998, 'LCAM': 0.674, 'LTCC': 0.987, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.xy.DefaultOH, embedding: {'CBO': 1.0, 'RFC': 33.0, 'SRFC': 17.0, 'DIT': 4.0, 'NOC': 0.0, 'WMC': 29.0, 'LOC': 94.0, 'CMLOC': 90.0, 'NOF': 2.0, 'NOSF': 0.0, 'NOM': 20.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.458, 'LCAM': 0.62, 'LTCC': 0.642, 'ATFD': 1.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.axis.NumberTickUnit, embedding: {'CBO': 1.0, 'RFC': 16.0, 'SRFC': 9.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 12.0, 'LOC': 39.0, 'CMLOC': 36.0, 'NOF': 1.0, 'NOSF': 1.0, 'NOM': 7.0, 'NOSM': 0.0, 'NORM': 1.0, 'LCOM': 0.6, 'LCAM': 0.571, 'LTCC': 0.286, 'ATFD': 0.0, 'SI': 0.286, 'Problematic': 0}
# Node: org.jfree.data.time.TimeSeriesCollection, embedding: {'CBO': 10.0, 'RFC': 107.0, 'SRFC': 50.0, 'DIT': 5.0, 'NOC': 0.0, 'WMC': 72.0, 'LOC': 237.0, 'CMLOC': 229.0, 'NOF': 3.0, 'NOSF': 1.0, 'NOM': 38.0, 'NOSM': 0.0, 'NORM': 2.0, 'LCOM': 0.667, 'LCAM': 0.863, 'LTCC': 0.68, 'ATFD': 3.0, 'SI': 0.263, 'Problematic': 1}
# Node: org.jfree.chart.text.format.RelativeDateFormat, embedding: {'CBO': 1.0, 'RFC': 43.0, 'SRFC': 19.0, 'DIT': 3.0, 'NOC': 0.0, 'WMC': 48.0, 'LOC': 172.0, 'CMLOC': 156.0, 'NOF': 12.0, 'NOSF': 2.0, 'NOM': 28.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.854, 'LCAM': 0.829, 'LTCC': 0.775, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.axis.AxisSpace, embedding: {'CBO': 2.0, 'RFC': 31.0, 'SRFC': 12.0, 'DIT': 1.0, 'NOC': 0.0, 'WMC': 43.0, 'LOC': 137.0, 'CMLOC': 131.0, 'NOF': 4.0, 'NOSF': 1.0, 'NOM': 19.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.494, 'LCAM': 0.711, 'LTCC': 0.246, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.text.TextBox, embedding: {'CBO': 6.0, 'RFC': 136.0, 'SRFC': 28.0, 'DIT': 1.0, 'NOC': 0.0, 'WMC': 48.0, 'LOC': 147.0, 'CMLOC': 137.0, 'NOF': 8.0, 'NOSF': 1.0, 'NOM': 25.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.758, 'LCAM': 0.871, 'LTCC': 0.632, 'ATFD': 1.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.urls.StandardPieUR, embedding: {'CBO': 2.0, 'RFC': 11.0, 'SRFC': 5.0, 'DIT': 1.0, 'NOC': 0.0, 'WMC': 14.0, 'LOC': 48.0, 'CMLOC': 43.0, 'NOF': 3.0, 'NOSF': 1.0, 'NOM': 6.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.375, 'LCAM': 0.639, 'LTCC': 0.8, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.time.SimpleTimePeriod, embedding: {'CBO': 0.0, 'RFC': 13.0, 'SRFC': 6.0, 'DIT': 1.0, 'NOC': 0.0, 'WMC': 20.0, 'LOC': 64.0, 'CMLOC': 60.0, 'NOF': 2.0, 'NOSF': 1.0, 'NOM': 9.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.667, 'LCAM': 0.639, 'LTCC': 0.694, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.annotations.XYAnnotation, embedding: {'CBO': 3.0, 'RFC': 1.0, 'SRFC': 0.0, 'DIT': 1.0, 'NOC': 1.0, 'WMC': 1.0, 'LOC': 4.0, 'CMLOC': 1.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 1.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.block., embedding: {'CBO': 10.0, 'RFC': 128.0, 'SRFC': 43.0, 'DIT': 1.0, 'NOC': 6.0, 'WMC': 55.0, 'LOC': 188.0, 'CMLOC': 179.0, 'NOF': 7.0, 'NOSF': 1.0, 'NOM': 38.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.772, 'LCAM': 0.855, 'LTCC': 0.779, 'ATFD': 3.0, 'SI': 0.0, 'Problematic': 1}
# Node: org.jfree.data.category.DefaultIntervalCategoryDataset, embedding: {'CBO': 4.0, 'RFC': 49.0, 'SRFC': 23.0, 'DIT': 3.0, 'NOC': 0.0, 'WMC': 92.0, 'LOC': 280.0, 'CMLOC': 274.0, 'NOF': 4.0, 'NOSF': 0.0, 'NOM': 31.0, 'NOSM': 2.0, 'NORM': 0.0, 'LCOM': 0.638, 'LCAM': 0.719, 'LTCC': 0.756, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.plot.dial.DialTextAnnotation, embedding: {'CBO': 8.0, 'RFC': 118.0, 'SRFC': 24.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 29.0, 'LOC': 110.0, 'CMLOC': 101.0, 'NOF': 6.0, 'NOSF': 1.0, 'NOM': 20.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.739, 'LCAM': 0.862, 'LTCC': 0.608, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.api.HorizontalAlignment, embedding: {'CBO': 0.0, 'RFC': 0.0, 'SRFC': 0.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 0.0, 'LOC': 4.0, 'CMLOC': 0.0, 'NOF': 0.0, 'NOSF': 3.0, 'NOM': 0.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.DefaultKeyedValues2D, embedding: {'CBO': 4.0, 'RFC': 64.0, 'SRFC': 38.0, 'DIT': 1.0, 'NOC': 0.0, 'WMC': 57.0, 'LOC': 186.0, 'CMLOC': 179.0, 'NOF': 4.0, 'NOSF': 1.0, 'NOM': 23.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.624, 'LCAM': 0.727, 'LTCC': 0.522, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.plot.CombinedRangeCategoryPlot, embedding: {'CBO': 17.0, 'RFC': 472.0, 'SRFC': 74.0, 'DIT': 3.0, 'NOC': 0.0, 'WMC': 64.0, 'LOC': 218.0, 'CMLOC': 212.0, 'NOF': 3.0, 'NOSF': 1.0, 'NOM': 21.0, 'NOSM': 0.0, 'NORM': 5.0, 'LCOM': 0.719, 'LCAM': 0.877, 'LTCC': 0.458, 'ATFD': 3.0, 'SI': 0.714, 'Problematic': 1}
# Node: org.jfree.data.DomainInfo, embedding: {'CBO': 1.0, 'RFC': 3.0, 'SRFC': 0.0, 'DIT': 1.0, 'NOC': 8.0, 'WMC': 3.0, 'LOC': 4.0, 'CMLOC': 3.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 3.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.renderer.category.IntervalBarRenderer, embedding: {'CBO': 14.0, 'RFC': 245.0, 'SRFC': 30.0, 'DIT': 4.0, 'NOC': 1.0, 'WMC': 20.0, 'LOC': 85.0, 'CMLOC': 83.0, 'NOF': 0.0, 'NOSF': 1.0, 'NOM': 5.0, 'NOSM': 0.0, 'NORM': 1.0, 'LCOM': 0.0, 'LCAM': 0.582, 'LTCC': 0.0, 'ATFD': 4.0, 'SI': 0.8, 'Problematic': 0}
# Node: org.jfree.chart.labels.PieSection, embedding: {'CBO': 1.0, 'RFC': 2.0, 'SRFC': 0.0, 'DIT': 1.0, 'NOC': 1.0, 'WMC': 2.0, 'LOC': 4.0, 'CMLOC': 2.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 2.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.xy.XYSeries, embedding: {'CBO': 4.0, 'RFC': 93.0, 'SRFC': 51.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 104.0, 'LOC': 304.0, 'CMLOC': 293.0, 'NOF': 8.0, 'NOSF': 1.0, 'NOM': 45.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.769, 'LCAM': 0.764, 'LTCC': 0.827, 'ATFD': 1.0, 'SI': 0.0, 'Problematic': 1}
# Node: org.jfree.data.KeyedValueComparatorType, embedding: {'CBO': 0.0, 'RFC': 0.0, 'SRFC': 0.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 0.0, 'LOC': 3.0, 'CMLOC': 0.0, 'NOF': 0.0, 'NOSF': 2.0, 'NOM': 0.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.plot.FastScatterPlot, embedding: {'CBO': 17.0, 'RFC': 250.0, 'SRFC': 75.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 100.0, 'LOC': 372.0, 'CMLOC': 349.0, 'NOF': 14.0, 'NOSF': 4.0, 'NOM': 50.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.91, 'LCAM': 0.876, 'LTCC': 0.802, 'ATFD': 4.0, 'SI': 0.0, 'Problematic': 2}
# Node: org.jfree.data.ItemKey, embedding: {'CBO': 0.0, 'RFC': 1.0, 'SRFC': 0.0, 'DIT': 1.0, 'NOC': 3.0, 'WMC': 1.0, 'LOC': 2.0, 'CMLOC': 1.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 1.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.title.Title, embedding: {'CBO': 8.0, 'RFC': 46.0, 'SRFC': 13.0, 'DIT': 2.0, 'NOC': 5.0, 'WMC': 37.0, 'LOC': 123.0, 'CMLOC': 107.0, 'NOF': 6.0, 'NOSF': 5.0, 'NOM': 23.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.885, 'LCAM': 0.863, 'LTCC': 0.816, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.Values, embedding: {'CBO': 0.0, 'RFC': 2.0, 'SRFC': 0.0, 'DIT': 1.0, 'NOC': 1.0, 'WMC': 2.0, 'LOC': 3.0, 'CMLOC': 2.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 2.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.25, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.plot.DialShape, embedding: {'CBO': 0.0, 'RFC': 0.0, 'SRFC': 0.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 0.0, 'LOC': 4.0, 'CMLOC': 0.0, 'NOF': 0.0, 'NOSF': 3.0, 'NOM': 0.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.renderer.xy.XYItemRenderer, embedding: {'CBO': 17.0, 'RFC': 132.0, 'SRFC': 0.0, 'DIT': 1.0, 'NOC': 20.0, 'WMC': 132.0, 'LOC': 141.0, 'CMLOC': 132.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 132.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.902, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 2}
# Node: org.jfree.chart.urls.CustomCategoryUR, embedding: {'CBO': 1.0, 'RFC': 13.0, 'SRFC': 8.0, 'DIT': 1.0, 'NOC': 0.0, 'WMC': 22.0, 'LOC': 59.0, 'CMLOC': 56.0, 'NOF': 1.0, 'NOSF': 0.0, 'NOM': 8.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.65, 'LTCC': 0.643, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.KeyedObject, embedding: {'CBO': 1.0, 'RFC': 11.0, 'SRFC': 4.0, 'DIT': 1.0, 'NOC': 0.0, 'WMC': 12.0, 'LOC': 39.0, 'CMLOC': 34.0, 'NOF': 2.0, 'NOSF': 1.0, 'NOM': 7.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.611, 'LCAM': 0.476, 'LTCC': 0.143, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.axis.AxisState, embedding: {'CBO': 2.0, 'RFC': 14.0, 'SRFC': 5.0, 'DIT': 1.0, 'NOC': 0.0, 'WMC': 17.0, 'LOC': 46.0, 'CMLOC': 42.0, 'NOF': 3.0, 'NOSF': 0.0, 'NOM': 13.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.7, 'LCAM': 0.558, 'LTCC': 0.679, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.time.TimePeriod, embedding: {'CBO': 0.0, 'RFC': 2.0, 'SRFC': 0.0, 'DIT': 1.0, 'NOC': 2.0, 'WMC': 2.0, 'LOC': 3.0, 'CMLOC': 2.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 2.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.plot.CombinedDomainCategoryPlot, embedding: {'CBO': 17.0, 'RFC': 559.0, 'SRFC': 88.0, 'DIT': 3.0, 'NOC': 0.0, 'WMC': 74.0, 'LOC': 257.0, 'CMLOC': 251.0, 'NOF': 3.0, 'NOSF': 1.0, 'NOM': 26.0, 'NOSM': 0.0, 'NORM': 9.0, 'LCOM': 0.721, 'LCAM': 0.87, 'LTCC': 0.652, 'ATFD': 4.0, 'SI': 1.038, 'Problematic': 1}
# Node: org.jfree.chart.urls.StandardXYUR, embedding: {'CBO': 2.0, 'RFC': 8.0, 'SRFC': 3.0, 'DIT': 1.0, 'NOC': 1.0, 'WMC': 11.0, 'LOC': 42.0, 'CMLOC': 34.0, 'NOF': 3.0, 'NOSF': 4.0, 'NOM': 5.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.75, 'LCAM': 0.6, 'LTCC': 0.6, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.xy.YInterval, embedding: {'CBO': 0.0, 'RFC': 5.0, 'SRFC': 0.0, 'DIT': 1.0, 'NOC': 0.0, 'WMC': 10.0, 'LOC': 28.0, 'CMLOC': 24.0, 'NOF': 3.0, 'NOSF': 0.0, 'NOM': 5.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.5, 'LCAM': 0.533, 'LTCC': 0.3, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.time.FixedMillisecond, embedding: {'CBO': 0.0, 'RFC': 19.0, 'SRFC': 3.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 24.0, 'LOC': 78.0, 'CMLOC': 74.0, 'NOF': 1.0, 'NOSF': 1.0, 'NOM': 17.0, 'NOSM': 0.0, 'NORM': 2.0, 'LCOM': 0.538, 'LCAM': 0.706, 'LTCC': 0.331, 'ATFD': 0.0, 'SI': 0.235, 'Problematic': 0}
# Node: org.jfree.data.general.SeriesDataset, embedding: {'CBO': 0.0, 'RFC': 3.0, 'SRFC': 0.0, 'DIT': 1.0, 'NOC': 2.0, 'WMC': 3.0, 'LOC': 4.0, 'CMLOC': 3.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 3.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.444, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.xy.XIntervalSeries, embedding: {'CBO': 2.0, 'RFC': 35.0, 'SRFC': 8.0, 'DIT': 3.0, 'NOC': 0.0, 'WMC': 9.0, 'LOC': 26.0, 'CMLOC': 24.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 9.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.63, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.annotations.XYAnnotationBoundsInfo, embedding: {'CBO': 1.0, 'RFC': 3.0, 'SRFC': 0.0, 'DIT': 1.0, 'NOC': 1.0, 'WMC': 3.0, 'LOC': 4.0, 'CMLOC': 3.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 3.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.title.ShortTextTitle, embedding: {'CBO': 7.0, 'RFC': 94.0, 'SRFC': 35.0, 'DIT': 4.0, 'NOC': 0.0, 'WMC': 26.0, 'LOC': 81.0, 'CMLOC': 80.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 7.0, 'NOSM': 0.0, 'NORM': 6.0, 'LCOM': 0.0, 'LCAM': 0.643, 'LTCC': 0.0, 'ATFD': 4.0, 'SI': 3.429, 'Problematic': 0}
# Node: org.jfree.data.xy.VectorSeriesCollection, embedding: {'CBO': 6.0, 'RFC': 60.0, 'SRFC': 25.0, 'DIT': 4.0, 'NOC': 0.0, 'WMC': 22.0, 'LOC': 83.0, 'CMLOC': 79.0, 'NOF': 1.0, 'NOSF': 0.0, 'NOM': 18.0, 'NOSM': 0.0, 'NORM': 2.0, 'LCOM': 0.0, 'LCAM': 0.556, 'LTCC': 0.405, 'ATFD': 1.0, 'SI': 0.444, 'Problematic': 0}
# Node: org.jfree.data.time.Quarter, embedding: {'CBO': 3.0, 'RFC': 45.0, 'SRFC': 22.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 37.0, 'LOC': 147.0, 'CMLOC': 131.0, 'NOF': 4.0, 'NOSF': 5.0, 'NOM': 21.0, 'NOSM': 1.0, 'NORM': 0.0, 'LCOM': 0.79, 'LCAM': 0.813, 'LTCC': 0.481, 'ATFD': 1.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.general.HeatMapDataset, embedding: {'CBO': 0.0, 'RFC': 10.0, 'SRFC': 0.0, 'DIT': 1.0, 'NOC': 1.0, 'WMC': 10.0, 'LOC': 11.0, 'CMLOC': 10.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 10.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.3, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.urls.CategoryUR, embedding: {'CBO': 1.0, 'RFC': 1.0, 'SRFC': 0.0, 'DIT': 1.0, 'NOC': 2.0, 'WMC': 1.0, 'LOC': 3.0, 'CMLOC': 1.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 1.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.renderer.xy.StandardXYBarPainter, embedding: {'CBO': 3.0, 'RFC': 42.0, 'SRFC': 18.0, 'DIT': 1.0, 'NOC': 0.0, 'WMC': 23.0, 'LOC': 73.0, 'CMLOC': 72.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 6.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.593, 'LTCC': 0.0, 'ATFD': 1.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.util.AttrStringUtils, embedding: {'CBO': 2.0, 'RFC': 32.0, 'SRFC': 27.0, 'DIT': 1.0, 'NOC': 0.0, 'WMC': 32.0, 'LOC': 141.0, 'CMLOC': 140.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 1.0, 'NOSM': 15.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.545, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.plot.dial.DialCap, embedding: {'CBO': 6.0, 'RFC': 89.0, 'SRFC': 21.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 23.0, 'LOC': 90.0, 'CMLOC': 83.0, 'NOF': 4.0, 'NOSF': 1.0, 'NOM': 16.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.631, 'LCAM': 0.837, 'LTCC': 0.56, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.swing.ChartMouse, embedding: {'CBO': 2.0, 'RFC': 4.0, 'SRFC': 0.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 4.0, 'LOC': 17.0, 'CMLOC': 12.0, 'NOF': 3.0, 'NOSF': 1.0, 'NOM': 4.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.833, 'LCAM': 0.562, 'LTCC': 0.5, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.renderer.Outlier, embedding: {'CBO': 0.0, 'RFC': 14.0, 'SRFC': 6.0, 'DIT': 1.0, 'NOC': 0.0, 'WMC': 18.0, 'LOC': 49.0, 'CMLOC': 46.0, 'NOF': 2.0, 'NOSF': 0.0, 'NOM': 11.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.417, 'LCAM': 0.691, 'LTCC': 0.727, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.axis.Timeline, embedding: {'CBO': 0.0, 'RFC': 7.0, 'SRFC': 0.0, 'DIT': 1.0, 'NOC': 1.0, 'WMC': 7.0, 'LOC': 8.0, 'CMLOC': 7.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 7.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.333, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.time.TimePeriodAnchor, embedding: {'CBO': 0.0, 'RFC': 0.0, 'SRFC': 0.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 0.0, 'LOC': 4.0, 'CMLOC': 0.0, 'NOF': 0.0, 'NOSF': 3.0, 'NOM': 0.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.entity.PieSectionEntity, embedding: {'CBO': 3.0, 'RFC': 19.0, 'SRFC': 5.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 18.0, 'LOC': 56.0, 'CMLOC': 49.0, 'NOF': 4.0, 'NOSF': 1.0, 'NOM': 12.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.709, 'LCAM': 0.738, 'LTCC': 0.455, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.annotations.XYTextAnnotation, embedding: {'CBO': 13.0, 'RFC': 170.0, 'SRFC': 42.0, 'DIT': 3.0, 'NOC': 1.0, 'WMC': 50.0, 'LOC': 205.0, 'CMLOC': 184.0, 'NOF': 12.0, 'NOSF': 6.0, 'NOM': 31.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.891, 'LCAM': 0.898, 'LTCC': 0.768, 'ATFD': 1.0, 'SI': 0.0, 'Problematic': 1}
# Node: org.jfree.chart.swing.editor.DefaultValueAxisEditor, embedding: {'CBO': 6.0, 'RFC': 101.0, 'SRFC': 41.0, 'DIT': 6.0, 'NOC': 2.0, 'WMC': 35.0, 'LOC': 169.0, 'CMLOC': 154.0, 'NOF': 11.0, 'NOSF': 1.0, 'NOM': 19.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.823, 'LCAM': 0.805, 'LTCC': 0.561, 'ATFD': 1.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.plot.IntervalMarker, embedding: {'CBO': 3.0, 'RFC': 48.0, 'SRFC': 5.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 17.0, 'LOC': 54.0, 'CMLOC': 49.0, 'NOF': 3.0, 'NOSF': 1.0, 'NOM': 11.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.714, 'LCAM': 0.714, 'LTCC': 0.709, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.statistics.BoxAndWhiskerItem, embedding: {'CBO': 0.0, 'RFC': 19.0, 'SRFC': 5.0, 'DIT': 1.0, 'NOC': 0.0, 'WMC': 26.0, 'LOC': 93.0, 'CMLOC': 82.0, 'NOF': 9.0, 'NOSF': 1.0, 'NOM': 14.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.75, 'LCAM': 0.729, 'LTCC': 0.593, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.block.BlockContainer, embedding: {'CBO': 10.0, 'RFC': 63.0, 'SRFC': 29.0, 'DIT': 2.0, 'NOC': 1.0, 'WMC': 26.0, 'LOC': 87.0, 'CMLOC': 82.0, 'NOF': 2.0, 'NOSF': 1.0, 'NOM': 15.0, 'NOSM': 0.0, 'NORM': 1.0, 'LCOM': 0.567, 'LCAM': 0.733, 'LTCC': 0.562, 'ATFD': 0.0, 'SI': 0.133, 'Problematic': 0}
# Node: org.jfree.chart.labels.BoxAndWhiskerToolTipGenerator, embedding: {'CBO': 3.0, 'RFC': 19.0, 'SRFC': 12.0, 'DIT': 3.0, 'NOC': 0.0, 'WMC': 7.0, 'LOC': 37.0, 'CMLOC': 30.0, 'NOF': 0.0, 'NOSF': 2.0, 'NOM': 4.0, 'NOSM': 0.0, 'NORM': 1.0, 'LCOM': 0.0, 'LCAM': 0.625, 'LTCC': 1.0, 'ATFD': 1.0, 'SI': 0.75, 'Problematic': 0}
# Node: org.jfree.data.xy.DefaultWindDataset, embedding: {'CBO': 2.0, 'RFC': 25.0, 'SRFC': 15.0, 'DIT': 4.0, 'NOC': 0.0, 'WMC': 28.0, 'LOC': 92.0, 'CMLOC': 88.0, 'NOF': 2.0, 'NOSF': 0.0, 'NOM': 12.0, 'NOSM': 1.0, 'NORM': 0.0, 'LCOM': 0.375, 'LCAM': 0.6, 'LTCC': 0.603, 'ATFD': 1.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.plot.Plot, embedding: {'CBO': 30.0, 'RFC': 248.0, 'SRFC': 63.0, 'DIT': 1.0, 'NOC': 13.0, 'WMC': 157.0, 'LOC': 459.0, 'CMLOC': 422.0, 'NOF': 18.0, 'NOSF': 12.0, 'NOM': 67.0, 'NOSM': 2.0, 'NORM': 0.0, 'LCOM': 0.95, 'LCAM': 0.942, 'LTCC': 0.953, 'ATFD': 2.0, 'SI': 0.0, 'Problematic': 2}
# ...
# Node: org.jfree.chart.plot.compass.MeterNeedle, embedding: {'CBO': 3.0, 'RFC': 100.0, 'SRFC': 27.0, 'DIT': 1.0, 'NOC': 8.0, 'WMC': 41.0, 'LOC': 119.0, 'CMLOC': 109.0, 'NOF': 7.0, 'NOSF': 2.0, 'NOM': 26.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.81, 'LCAM': 0.833, 'LTCC': 0.784, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.xy.IntervalXYDelegate, embedding: {'CBO': 6.0, 'RFC': 43.0, 'SRFC': 20.0, 'DIT': 1.0, 'NOC': 0.0, 'WMC': 43.0, 'LOC': 127.0, 'CMLOC': 119.0, 'NOF': 5.0, 'NOSF': 1.0, 'NOM': 22.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.765, 'LCAM': 0.753, 'LTCC': 0.716, 'ATFD': 1.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.plot.CenterTextMode, embedding: {'CBO': 0.0, 'RFC': 0.0, 'SRFC': 0.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 0.0, 'LOC': 4.0, 'CMLOC': 0.0, 'NOF': 0.0, 'NOSF': 3.0, 'NOM': 0.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.xml.DatasetTags, embedding: {'CBO': 0.0, 'RFC': 0.0, 'SRFC': 0.0, 'DIT': 1.0, 'NOC': 7.0, 'WMC': 0.0, 'LOC': 7.0, 'CMLOC': 0.0, 'NOF': 0.0, 'NOSF': 6.0, 'NOM': 0.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.statistics.DefaultBoxAndWhiskerXYDataset, embedding: {'CBO': 4.0, 'RFC': 52.0, 'SRFC': 21.0, 'DIT': 4.0, 'NOC': 0.0, 'WMC': 49.0, 'LOC': 177.0, 'CMLOC': 166.0, 'NOF': 8.0, 'NOSF': 0.0, 'NOM': 28.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.84, 'LCAM': 0.768, 'LTCC': 0.646, 'ATFD': 1.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.swing.editor.DefaultPlotEditor, embedding: {'CBO': 16.0, 'RFC': 125.0, 'SRFC': 75.0, 'DIT': 5.0, 'NOC': 1.0, 'WMC': 67.0, 'LOC': 268.0, 'CMLOC': 249.0, 'NOF': 13.0, 'NOSF': 4.0, 'NOM': 17.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.891, 'LCAM': 0.569, 'LTCC': 0.944, 'ATFD': 7.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.swing.ChartMouseEvent, embedding: {'CBO': 2.0, 'RFC': 4.0, 'SRFC': 0.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 4.0, 'LOC': 17.0, 'CMLOC': 12.0, 'NOF': 3.0, 'NOSF': 1.0, 'NOM': 4.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.833, 'LCAM': 0.562, 'LTCC': 0.5, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.gantt.SlidingGanttCategoryDataset, embedding: {'CBO': 2.0, 'RFC': 59.0, 'SRFC': 25.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 63.0, 'LOC': 208.0, 'CMLOC': 203.0, 'NOF': 3.0, 'NOSF': 0.0, 'NOM': 33.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.417, 'LCAM': 0.63, 'LTCC': 0.137, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.labels.StandardXYZToolTipGenerator, embedding: {'CBO': 4.0, 'RFC': 30.0, 'SRFC': 20.0, 'DIT': 3.0, 'NOC': 0.0, 'WMC': 18.0, 'LOC': 78.0, 'CMLOC': 72.0, 'NOF': 2.0, 'NOSF': 2.0, 'NOM': 10.0, 'NOSM': 0.0, 'NORM': 1.0, 'LCOM': 0.75, 'LCAM': 0.737, 'LTCC': 0.694, 'ATFD': 1.0, 'SI': 0.3, 'Problematic': 0}
# Node: org.jfree.data.DomainOrder, embedding: {'CBO': 0.0, 'RFC': 0.0, 'SRFC': 0.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 0.0, 'LOC': 4.0, 'CMLOC': 0.0, 'NOF': 0.0, 'NOSF': 3.0, 'NOM': 0.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.category.SlidingCategoryDataset, embedding: {'CBO': 2.0, 'RFC': 40.0, 'SRFC': 19.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 36.0, 'LOC': 107.0, 'CMLOC': 102.0, 'NOF': 3.0, 'NOSF': 0.0, 'NOM': 20.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.456, 'LCAM': 0.733, 'LTCC': 0.234, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.renderer.category.StackedAreaRenderer, embedding: {'CBO': 12.0, 'RFC': 198.0, 'SRFC': 34.0, 'DIT': 4.0, 'NOC': 0.0, 'WMC': 42.0, 'LOC': 216.0, 'CMLOC': 212.0, 'NOF': 1.0, 'NOSF': 1.0, 'NOM': 11.0, 'NOSM': 0.0, 'NORM': 3.0, 'LCOM': 0.583, 'LCAM': 0.795, 'LTCC': 0.464, 'ATFD': 2.0, 'SI': 1.091, 'Problematic': 1}
# Node: org.jfree.data.KeyedValues2D, embedding: {'CBO': 0.0, 'RFC': 7.0, 'SRFC': 0.0, 'DIT': 1.0, 'NOC': 2.0, 'WMC': 7.0, 'LOC': 9.0, 'CMLOC': 7.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 7.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.536, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.swing.NumberCellRenderer, embedding: {'CBO': 0.0, 'RFC': 9.0, 'SRFC': 7.0, 'DIT': 6.0, 'NOC': 0.0, 'WMC': 4.0, 'LOC': 19.0, 'CMLOC': 18.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 2.0, 'NOSM': 0.0, 'NORM': 1.0, 'LCOM': 0.0, 'LCAM': 0.4, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 3.0, 'Problematic': 0}
# Node: org.jfree.chart.renderer.xy.CandlestickRenderer, embedding: {'CBO': 19.0, 'RFC': 211.0, 'SRFC': 50.0, 'DIT': 3.0, 'NOC': 0.0, 'WMC': 77.0, 'LOC': 309.0, 'CMLOC': 291.0, 'NOF': 12.0, 'NOSF': 4.0, 'NOM': 30.0, 'NOSM': 0.0, 'NORM': 2.0, 'LCOM': 0.893, 'LCAM': 0.878, 'LTCC': 0.82, 'ATFD': 2.0, 'SI': 0.2, 'Problematic': 1}
# Node: org.jfree.data.KeyedValueComparator, embedding: {'CBO': 4.0, 'RFC': 10.0, 'SRFC': 6.0, 'DIT': 1.0, 'NOC': 0.0, 'WMC': 18.0, 'LOC': 55.0, 'CMLOC': 52.0, 'NOF': 2.0, 'NOSF': 0.0, 'NOM': 4.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.333, 'LCAM': 0.562, 'LTCC': 0.167, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.event.ChartChangeEventType, embedding: {'CBO': 0.0, 'RFC': 0.0, 'SRFC': 0.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 0.0, 'LOC': 4.0, 'CMLOC': 0.0, 'NOF': 0.0, 'NOSF': 3.0, 'NOM': 0.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.renderer.xy.XYErrorRenderer, embedding: {'CBO': 14.0, 'RFC': 309.0, 'SRFC': 29.0, 'DIT': 4.0, 'NOC': 0.0, 'WMC': 37.0, 'LOC': 149.0, 'CMLOC': 142.0, 'NOF': 5.0, 'NOSF': 1.0, 'NOM': 17.0, 'NOSM': 0.0, 'NORM': 2.0, 'LCOM': 0.726, 'LCAM': 0.875, 'LTCC': 0.638, 'ATFD': 1.0, 'SI': 0.471, 'Problematic': 1}
# Node: org.jfree.chart.labels.StandardCategorySeries, embedding: {'CBO': 3.0, 'RFC': 14.0, 'SRFC': 7.0, 'DIT': 1.0, 'NOC': 0.0, 'WMC': 10.0, 'LOC': 39.0, 'CMLOC': 34.0, 'NOF': 1.0, 'NOSF': 2.0, 'NOM': 7.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.833, 'LCAM': 0.629, 'LTCC': 0.6, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.plot.flow.FlowPlot, embedding: {'CBO': 18.0, 'RFC': 184.0, 'SRFC': 73.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 88.0, 'LOC': 331.0, 'CMLOC': 315.0, 'NOF': 14.0, 'NOSF': 0.0, 'NOM': 34.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.862, 'LCAM': 0.893, 'LTCC': 0.782, 'ATFD': 2.0, 'SI': 0.0, 'Problematic': 1}
# Node: org.jfree.chart.axis.ExtendedCategoryAxis, embedding: {'CBO': 9.0, 'RFC': 107.0, 'SRFC': 17.0, 'DIT': 3.0, 'NOC': 0.0, 'WMC': 22.0, 'LOC': 67.0, 'CMLOC': 62.0, 'NOF': 3.0, 'NOSF': 1.0, 'NOM': 11.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.675, 'LCAM': 0.81, 'LTCC': 0.429, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.plot.Crosshair, embedding: {'CBO': 7.0, 'RFC': 111.0, 'SRFC': 21.0, 'DIT': 1.0, 'NOC': 0.0, 'WMC': 57.0, 'LOC': 219.0, 'CMLOC': 202.0, 'NOF': 16.0, 'NOSF': 0.0, 'NOM': 40.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.844, 'LCAM': 0.867, 'LTCC': 0.65, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 1}
# Node: org.jfree.data.xml.CategoryDatasetHandler, embedding: {'CBO': 6.0, 'RFC': 38.0, 'SRFC': 8.0, 'DIT': 3.0, 'NOC': 0.0, 'WMC': 9.0, 'LOC': 31.0, 'CMLOC': 29.0, 'NOF': 1.0, 'NOSF': 0.0, 'NOM': 5.0, 'NOSM': 0.0, 'NORM': 2.0, 'LCOM': 0.0, 'LCAM': 0.6, 'LTCC': 0.4, 'ATFD': 0.0, 'SI': 1.2, 'Problematic': 0}
# Node: org.jfree.chart.annotations.CategoryTextAnnotation, embedding: {'CBO': 11.0, 'RFC': 133.0, 'SRFC': 30.0, 'DIT': 3.0, 'NOC': 1.0, 'WMC': 19.0, 'LOC': 87.0, 'CMLOC': 80.0, 'NOF': 3.0, 'NOSF': 1.0, 'NOM': 11.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.611, 'LCAM': 0.81, 'LTCC': 0.4, 'ATFD': 1.0, 'SI': 0.0, 'Problematic': 1}
# Node: org.jfree.chart.plot.XYCrosshairState, embedding: {'CBO': 0.0, 'RFC': 1.0, 'SRFC': 0.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 1.0, 'LOC': 2.0, 'CMLOC': 1.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 1.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.renderer.xy.XYDotRenderer, embedding: {'CBO': 14.0, 'RFC': 178.0, 'SRFC': 39.0, 'DIT': 3.0, 'NOC': 0.0, 'WMC': 30.0, 'LOC': 117.0, 'CMLOC': 111.0, 'NOF': 3.0, 'NOSF': 1.0, 'NOM': 13.0, 'NOSM': 0.0, 'NORM': 1.0, 'LCOM': 0.7, 'LCAM': 0.841, 'LTCC': 0.6, 'ATFD': 1.0, 'SI': 0.231, 'Problematic': 1}
# Node: org.jfree.chart.entity.TitleEntity, embedding: {'CBO': 4.0, 'RFC': 71.0, 'SRFC': 15.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 16.0, 'LOC': 52.0, 'CMLOC': 49.0, 'NOF': 1.0, 'NOSF': 1.0, 'NOM': 10.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.75, 'LCAM': 0.7, 'LTCC': 0.893, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.internal., embedding: {'CBO': 0.0, 'RFC': 6.0, 'SRFC': 1.0, 'DIT': 1.0, 'NOC': 0.0, 'WMC': 11.0, 'LOC': 22.0, 'CMLOC': 21.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 0.0, 'NOSM': 5.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.4, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.plot.SpiderWebPlot, embedding: {'CBO': 23.0, 'RFC': 346.0, 'SRFC': 111.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 128.0, 'LOC': 522.0, 'CMLOC': 482.0, 'NOF': 23.0, 'NOSF': 13.0, 'NOM': 62.0, 'NOSM': 0.0, 'NORM': 1.0, 'LCOM': 0.946, 'LCAM': 0.913, 'LTCC': 0.899, 'ATFD': 2.0, 'SI': 0.032, 'Problematic': 2}
# Node: org.jfree.chart.axis.MonthDateFormat, embedding: {'CBO': 1.0, 'RFC': 25.0, 'SRFC': 15.0, 'DIT': 3.0, 'NOC': 0.0, 'WMC': 19.0, 'LOC': 63.0, 'CMLOC': 59.0, 'NOF': 3.0, 'NOSF': 0.0, 'NOM': 10.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.742, 'LTCC': 0.933, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.plot.ValueAxisPlot, embedding: {'CBO': 2.0, 'RFC': 1.0, 'SRFC': 0.0, 'DIT': 1.0, 'NOC': 5.0, 'WMC': 1.0, 'LOC': 2.0, 'CMLOC': 1.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 1.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.time.TimeSeriesTableModel, embedding: {'CBO': 3.0, 'RFC': 39.0, 'SRFC': 9.0, 'DIT': 2.0, 'NOC': 0.0, 'WMC': 28.0, 'LOC': 82.0, 'CMLOC': 76.0, 'NOF': 4.0, 'NOSF': 0.0, 'NOM': 11.0, 'NOSM': 0.0, 'NORM': 4.0, 'LCOM': 0.625, 'LCAM': 0.682, 'LTCC': 0.873, 'ATFD': 0.0, 'SI': 0.727, 'Problematic': 0}
# Node: org.jfree.data.xy.XYIntervalSeries, embedding: {'CBO': 2.0, 'RFC': 41.0, 'SRFC': 10.0, 'DIT': 3.0, 'NOC': 0.0, 'WMC': 11.0, 'LOC': 33.0, 'CMLOC': 31.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 11.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.636, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.xy.XYSeriesCollection, embedding: {'CBO': 10.0, 'RFC': 121.0, 'SRFC': 55.0, 'DIT': 5.0, 'NOC': 0.0, 'WMC': 82.0, 'LOC': 257.0, 'CMLOC': 250.0, 'NOF': 2.0, 'NOSF': 1.0, 'NOM': 39.0, 'NOSM': 0.0, 'NORM': 1.0, 'LCOM': 0.642, 'LCAM': 0.826, 'LTCC': 0.671, 'ATFD': 3.0, 'SI': 0.128, 'Problematic': 1}
# Node: org.jfree.chart.block.BlockResult, embedding: {'CBO': 1.0, 'RFC': 3.0, 'SRFC': 0.0, 'DIT': 1.0, 'NOC': 0.0, 'WMC': 3.0, 'LOC': 9.0, 'CMLOC': 7.0, 'NOF': 1.0, 'NOSF': 0.0, 'NOM': 3.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.333, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.renderer.xy.XYAreaRenderer, embedding: {'CBO': 20.0, 'RFC': 224.0, 'SRFC': 76.0, 'DIT': 3.0, 'NOC': 1.0, 'WMC': 70.0, 'LOC': 287.0, 'CMLOC': 265.0, 'NOF': 7.0, 'NOSF': 6.0, 'NOM': 22.0, 'NOSM': 0.0, 'NORM': 2.0, 'LCOM': 0.887, 'LCAM': 0.879, 'LTCC': 0.732, 'ATFD': 1.0, 'SI': 0.273, 'Problematic': 1}
# Node: org.jfree.chart.block.GridArrangement, embedding: {'CBO': 6.0, 'RFC': 35.0, 'SRFC': 30.0, 'DIT': 1.0, 'NOC': 0.0, 'WMC': 51.0, 'LOC': 178.0, 'CMLOC': 174.0, 'NOF': 2.0, 'NOSF': 1.0, 'NOM': 14.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.4, 'LCAM': 0.52, 'LTCC': 0.9, 'ATFD': 2.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.data.statistics.SimpleHistogramDataset, embedding: {'CBO': 7.0, 'RFC': 59.0, 'SRFC': 26.0, 'DIT': 5.0, 'NOC': 0.0, 'WMC': 44.0, 'LOC': 130.0, 'CMLOC': 123.0, 'NOF': 3.0, 'NOSF': 1.0, 'NOM': 28.0, 'NOSM': 0.0, 'NORM': 7.0, 'LCOM': 0.683, 'LCAM': 0.745, 'LTCC': 0.762, 'ATFD': 1.0, 'SI': 1.25, 'Problematic': 0}
# Node: org.jfree.chart.plot.compass.ArrowNeedle, embedding: {'CBO': 1.0, 'RFC': 64.0, 'SRFC': 19.0, 'DIT': 2.0, 'NOC': 1.0, 'WMC': 14.0, 'LOC': 56.0, 'CMLOC': 52.0, 'NOF': 1.0, 'NOSF': 1.0, 'NOM': 5.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.667, 'LCAM': 0.686, 'LTCC': 0.5, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.imagemap.ToolTipTagFragmentGenerator, embedding: {'CBO': 0.0, 'RFC': 1.0, 'SRFC': 0.0, 'DIT': 1.0, 'NOC': 3.0, 'WMC': 1.0, 'LOC': 2.0, 'CMLOC': 1.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 1.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.swing.ChartFrame, embedding: {'CBO': 2.0, 'RFC': 5.0, 'SRFC': 2.0, 'DIT': 6.0, 'NOC': 0.0, 'WMC': 4.0, 'LOC': 14.0, 'CMLOC': 12.0, 'NOF': 1.0, 'NOSF': 0.0, 'NOM': 3.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.333, 'LTCC': 0.667, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.renderer.category.StatisticalBarRenderer, embedding: {'CBO': 16.0, 'RFC': 270.0, 'SRFC': 41.0, 'DIT': 4.0, 'NOC': 0.0, 'WMC': 62.0, 'LOC': 250.0, 'CMLOC': 244.0, 'NOF': 2.0, 'NOSF': 1.0, 'NOM': 12.0, 'NOSM': 0.0, 'NORM': 2.0, 'LCOM': 0.519, 'LCAM': 0.767, 'LTCC': 0.607, 'ATFD': 2.0, 'SI': 0.667, 'Problematic': 1}
# Node: org.jfree.chart.block.EntityBlockParams, embedding: {'CBO': 0.0, 'RFC': 1.0, 'SRFC': 0.0, 'DIT': 1.0, 'NOC': 1.0, 'WMC': 1.0, 'LOC': 2.0, 'CMLOC': 1.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 1.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.event.PlotChange, embedding: {'CBO': 1.0, 'RFC': 2.0, 'SRFC': 0.0, 'DIT': 3.0, 'NOC': 0.0, 'WMC': 2.0, 'LOC': 7.0, 'CMLOC': 5.0, 'NOF': 1.0, 'NOSF': 0.0, 'NOM': 2.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.25, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.swing.UIUtils, embedding: {'CBO': 1.0, 'RFC': 34.0, 'SRFC': 27.0, 'DIT': 1.0, 'NOC': 0.0, 'WMC': 13.0, 'LOC': 55.0, 'CMLOC': 54.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 1.0, 'NOSM': 9.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.687, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.event.PlotChangeEvent, embedding: {'CBO': 1.0, 'RFC': 2.0, 'SRFC': 0.0, 'DIT': 3.0, 'NOC': 0.0, 'WMC': 2.0, 'LOC': 7.0, 'CMLOC': 5.0, 'NOF': 1.0, 'NOSF': 0.0, 'NOM': 2.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.25, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.event.MarkerChangeEvent, embedding: {'CBO': 1.0, 'RFC': 2.0, 'SRFC': 0.0, 'DIT': 3.0, 'NOC': 0.0, 'WMC': 2.0, 'LOC': 7.0, 'CMLOC': 5.0, 'NOF': 1.0, 'NOSF': 0.0, 'NOM': 2.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.25, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.text.format., embedding: {'CBO': 0.0, 'RFC': 6.0, 'SRFC': 3.0, 'DIT': 3.0, 'NOC': 0.0, 'WMC': 4.0, 'LOC': 22.0, 'CMLOC': 20.0, 'NOF': 1.0, 'NOSF': 0.0, 'NOM': 4.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.571, 'LTCC': 1.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.labels.XYToolTipGenerator, embedding: {'CBO': 1.0, 'RFC': 1.0, 'SRFC': 0.0, 'DIT': 1.0, 'NOC': 7.0, 'WMC': 1.0, 'LOC': 2.0, 'CMLOC': 1.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 1.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.plot.DrawingSupplier, embedding: {'CBO': 0.0, 'RFC': 6.0, 'SRFC': 0.0, 'DIT': 1.0, 'NOC': 1.0, 'WMC': 6.0, 'LOC': 7.0, 'CMLOC': 6.0, 'NOF': 0.0, 'NOSF': 0.0, 'NOM': 6.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.0, 'LCAM': 0.0, 'LTCC': 0.0, 'ATFD': 0.0, 'SI': 0.0, 'Problematic': 0}
# Node: org.jfree.chart.labels.StandardCrosshair, embedding: {'CBO': 2.0, 'RFC': 15.0, 'SRFC': 8.0, 'DIT': 1.0, 'NOC': 0.0, 'WMC': 11.0, 'LOC': 39.0, 'CMLOC': 35.0, 'NOF': 2.0, 'NOSF': 0.0, 'NOM': 7.0, 'NOSM': 0.0, 'NORM': 0.0, 'LCOM': 0.3, 'LCAM': 0.686, 'LTCC': 0.381, 'ATFD': 1.0, 'SI': 0.0, 'Problematic': 0}

# %%
import torch
from torch_geometric.data import Data

def networkx_to_pyg_data(graph):
    node_features_list = []
    labels = []
    node_mapping = {}
    node_index = 0

    for node, node_data in graph.nodes(data=True):
        node_mapping[node] = node_index
        features = [node_data['CBO'],
                    node_data['RFC'],
                    node_data['SRFC'],
                    node_data['DIT'],
                    node_data['NOC'],
                    node_data['WMC'],
                    node_data['LOC'],
                    node_data['CMLOC'],
                    node_data['NOF'],
                    node_data['NOSF'],
                    node_data['NOM'],
                    node_data['NOSM'],
                    node_data['NORM'],
                    node_data['LCOM'],
                    node_data['LCAM'],
                    node_data['LTCC'],
                    node_data['ATFD'],
                    node_data['SI']]
        node_features_list.append(features)
        labels.append(node_data['Problematic'])
        node_index += 1

    edge_index = []
    for source, target in graph.edges():
        edge_index.append([node_mapping[source], node_mapping[target]])
    
    edge_index = torch.tensor(edge_index, dtype=torch.long).t().contiguous()
    x = torch.tensor(node_features_list, dtype=torch.float)
    y = torch.tensor(labels, dtype=torch.long)

    return Data(x=x, edge_index=edge_index, y=y)

pyg_data = networkx_to_pyg_data(G)

# %%
def add_num_classes_to_pyg_data(data):
    num_classes = data.y.unique().size(0)
    data.num_classes = num_classes
    
add_num_classes_to_pyg_data(pyg_data)

print(f"Number of classes: {pyg_data.num_classes}")
# Out:
# Number of classes: 3

# %%
print(f'Dataset: {pyg_data}:')
print('======================')
print(f'Number of graphs: {len(pyg_data)}')
print(f'Number of features: {pyg_data.num_features}')
print(f'Number of classes: {pyg_data.num_classes}')
print(f'Number of nodes: {pyg_data.num_nodes}')
print(f'Number of edges: {pyg_data.num_edges}')
print(f'Average node degree: {pyg_data.num_edges / pyg_data.num_nodes:.2f}')
print(f'Has isolated nodes: {pyg_data.has_isolated_nodes()}')
print(f'Has self-loops: {pyg_data.has_self_loops()}')
print(f'Is undirected: {pyg_data.is_undirected()}')
# Out:
# Dataset: Data(x=[589, 18], edge_index=[2, 6357], y=[589], num_classes=3):
# ======================
# Number of graphs: 4
# Number of features: 18
# Number of classes: 3
# Number of nodes: 589
# Number of edges: 6357
# Average node degree: 10.79
# Has isolated nodes: False
# Has self-loops: True
# Is undirected: False

# %%
def save_pyg_dataset(dataset, file_path):
    torch.save(dataset, file_path)

# Assuming 'pyg_dataset' is the dataset you want to save
output_file_path = "output/" + project_name + "/pyg_dataset_for_problematic_class.pt"
save_pyg_dataset(pyg_data, output_file_path)

# %%
import networkx as nx
from torch_geometric.utils import to_networkx

def visualize_graph(G, color):
    plt.figure(figsize=(7,7))
    plt.xticks([])
    plt.yticks([])
    nx.draw_networkx(G, pos=nx.spring_layout(G, seed=42), with_labels=False,
                     node_color=color, cmap="Set2")
    plt.show()

G = to_networkx(pyg_data, to_undirected=True)
visualize_graph(G, color=pyg_data.y)

# %%
import torch
from torch.nn import Linear
from torch_geometric.nn import GCNConv

class GCN(torch.nn.Module):
    def __init__(self):
        super().__init__()
        torch.manual_seed(1234)
        self.conv1 = GCNConv(pyg_data.num_features, 16)
        self.classifier = Linear(16, pyg_data.num_classes)

    def forward(self, x, edge_index):
        h = self.conv1(x, edge_index)
        h = h.tanh()  # Final GNN embedding space.
        
        # Apply a final (linear) classifier.
        out = self.classifier(h)

        return out, h

model = GCN()
print(model)
# Out:
# GCN(
#   (conv1): GCNConv(18, 16)
#   (classifier): Linear(in_features=16, out_features=3, bias=True)
# )

# %%
model = GCN()

_, h = model(pyg_data.x, pyg_data.edge_index)
print(f'Embedding shape: {list(h.shape)}')

def visualize_embedding(h, color, epoch=None, loss=None):
    plt.figure(figsize=(7,7))
    plt.xticks([])
    plt.yticks([])
    h = h.detach().cpu().numpy()
    plt.scatter(h[:, 0], h[:, 1], s=140, c=color, cmap="Set2")
    if epoch is not None and loss is not None:
        plt.xlabel(f'Epoch: {epoch}, Loss: {loss.item():.4f}', fontsize=16)
    plt.show()

visualize_embedding(h, color=pyg_data.y)
# Out:
# Embedding shape: [589, 16]

# %%
import random

def add_train_mask_to_pyg_data(data, train_ratio=0.8):
    num_nodes = data.num_nodes
    num_train_nodes = int(train_ratio * num_nodes)

    # Generate a list of True and False values with the specified ratio
    mask_values = [True] * num_train_nodes + [False] * (num_nodes - num_train_nodes)

    # Randomly shuffle the mask values
    random.shuffle(mask_values)

    # Convert the mask_values list to a boolean tensor and assign it to the Data object
    data.train_mask = torch.tensor(mask_values, dtype=torch.bool)

# Example usage
add_train_mask_to_pyg_data(pyg_data, train_ratio=0.8)

print(f"Train mask: {pyg_data.train_mask}")
# Out:
# Train mask: tensor([ True,  True,  True, False,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True, False,  True,  True,  True,  True,  True,
#          True, False,  True, False,  True, False,  True, False, False,  True,
#          True,  True,  True,  True, False,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True, False,  True,  True,  True,  True, False,
#         False,  True, False,  True, False,  True,  True,  True,  True,  True,
#         False,  True, False,  True,  True,  True,  True,  True,  True, False,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#         False,  True,  True,  True,  True,  True,  True,  True,  True, False,
#          True,  True, False,  True,  True,  True,  True, False,  True,  True,
#         False, False,  True,  True,  True,  True, False, False, False,  True,
#          True,  True,  True,  True, False,  True,  True,  True, False,  True,
#         False,  True,  True, False,  True, False,  True,  True,  True,  True,
#          True,  True, False,  True,  True,  True,  True,  True,  True,  True,
#          True, False,  True,  True,  True,  True,  True,  True,  True, False,
#          True, False,  True, False,  True, False,  True,  True, False,  True,
#          True, False, False,  True,  True,  True,  True,  True,  True, False,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True, False,  True,  True, False, False,  True,  True,
#         False,  True, False,  True,  True, False,  True,  True,  True,  True,
#         False,  True,  True,  True,  True, False,  True,  True,  True,  True,
#          True,  True, False,  True,  True,  True,  True,  True,  True,  True,
#         False, False,  True,  True,  True, False,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True, False,
#          True,  True, False,  True, False,  True,  True, False,  True,  True,
#         False, False,  True,  True, False,  True,  True,  True,  True, False,
#          True,  True, False,  True,  True,  True,  True,  True,  True, False,
#         False,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#         False,  True,  True,  True,  True, False,  True, False,  True,  True,
#          True,  True, False,  True, False, False,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True, False,  True,  True,
#          True,  True,  True,  True,  True, False,  True,  True, False,  True,
#          True,  True, False,  True, False, False, False,  True,  True,  True,
#         False, False, False,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True, False,  True, False,  True,  True,
#          True, False,  True, False,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True, False,  True,  True,  True,
#          True,  True, False,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True, False,  True,  True,  True, False,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True, False,  True,  True, False,  True,  True,  True,  True,  True,
#          True, False,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True, False, False, False, False, False,  True, False, False,
#          True,  True, False,  True,  True,  True,  True, False,  True,  True,
#          True,  True,  True,  True,  True,  True, False,  True,  True,  True,
#         False, False, False,  True,  True, False, False,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True, False,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True, False,
#          True,  True,  True,  True,  True, False, False,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True, False,  True,  True,  True,  True,  True, False,  True,
#          True, False,  True,  True,  True,  True,  True, False,  True,  True,
#          True,  True,  True,  True,  True,  True,  True, False,  True,  True,
#          True,  True,  True,  True,  True, False,  True,  True,  True,  True,
#          True,  True,  True, False,  True, False,  True,  True,  True,  True,
#          True,  True,  True, False,  True,  True,  True,  True,  True])

# %%
import time
from IPython.display import Javascript  # Restrict height of output cell.
display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 430})'''))

model = GCN()
criterion = torch.nn.CrossEntropyLoss()  # Define loss criterion.
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)  # Define optimizer.

def train(data):
    optimizer.zero_grad()  # Clear gradients.
    out, h = model(data.x, data.edge_index)  # Perform a single forward pass.
    loss = criterion(out[data.train_mask], data.y[data.train_mask])  # Compute the loss solely based on the training nodes.
    loss.backward()  # Derive gradients.
    optimizer.step()  # Update parameters based on gradients.
    return loss, h

for epoch in range(1001):
    loss, h = train(pyg_data)
    if epoch % 100 == 0:
        visualize_embedding(h, color=pyg_data.y, epoch=epoch, loss=loss)
        time.sleep(0.3)

# %%
def add_test_mask_to_pyg_data(data):
    # If the train_mask is not set, raise an exception
    if not hasattr(data, 'train_mask'):
        raise ValueError("Please add a train_mask to the Data object first.")
    
    # Create a test mask as the complement of the train mask
    data.test_mask = ~data.train_mask

add_test_mask_to_pyg_data(pyg_data)

print(f"Test mask: {pyg_data.test_mask}")
# Out:
# Test mask: tensor([False, False, False,  True, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False, False,
#         False, False, False, False,  True, False, False, False, False, False,
#         False,  True, False,  True, False,  True, False,  True,  True, False,
#         False, False, False, False,  True, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False, False,
#         False, False, False, False,  True, False, False, False, False,  True,
#          True, False,  True, False,  True, False, False, False, False, False,
#          True, False,  True, False, False, False, False, False, False,  True,
#         False, False, False, False, False, False, False, False, False, False,
#          True, False, False, False, False, False, False, False, False,  True,
#         False, False,  True, False, False, False, False,  True, False, False,
#          True,  True, False, False, False, False,  True,  True,  True, False,
#         False, False, False, False,  True, False, False, False,  True, False,
#          True, False, False,  True, False,  True, False, False, False, False,
#         False, False,  True, False, False, False, False, False, False, False,
#         False,  True, False, False, False, False, False, False, False,  True,
#         False,  True, False,  True, False,  True, False, False,  True, False,
#         False,  True,  True, False, False, False, False, False, False,  True,
#         False, False, False, False, False, False, False, False, False, False,
#         False, False, False,  True, False, False,  True,  True, False, False,
#          True, False,  True, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#         False, False,  True, False, False, False, False, False, False, False,
#          True,  True, False, False, False,  True, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,  True,
#         False, False,  True, False,  True, False, False,  True, False, False,
#          True,  True, False, False,  True, False, False, False, False,  True,
#         False, False,  True, False, False, False, False, False, False,  True,
#          True, False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False, False,
#          True, False, False, False, False,  True, False,  True, False, False,
#         False, False,  True, False,  True,  True, False, False, False, False,
#         False, False, False, False, False, False, False,  True, False, False,
#         False, False, False, False, False,  True, False, False,  True, False,
#         False, False,  True, False,  True,  True,  True, False, False, False,
#          True,  True,  True, False, False, False, False, False, False, False,
#         False, False, False, False, False,  True, False,  True, False, False,
#         False,  True, False,  True, False, False, False, False, False, False,
#         False, False, False, False, False, False,  True, False, False, False,
#         False, False,  True, False, False, False, False, False, False, False,
#         False, False, False, False,  True, False, False, False,  True, False,
#         False, False, False, False, False, False, False, False, False, False,
#         False,  True, False, False,  True, False, False, False, False, False,
#         False,  True, False, False, False, False, False, False, False, False,
#         False, False,  True,  True,  True,  True,  True, False,  True,  True,
#         False, False,  True, False, False, False, False,  True, False, False,
#         False, False, False, False, False, False,  True, False, False, False,
#          True,  True,  True, False, False,  True,  True, False, False, False,
#         False, False, False, False, False, False, False, False,  True, False,
#         False, False, False, False, False, False, False, False, False,  True,
#         False, False, False, False, False,  True,  True, False, False, False,
#         False, False, False, False, False, False, False, False, False, False,
#         False, False,  True, False, False, False, False, False,  True, False,
#         False,  True, False, False, False, False, False,  True, False, False,
#         False, False, False, False, False, False, False,  True, False, False,
#         False, False, False, False, False,  True, False, False, False, False,
#         False, False, False,  True, False,  True, False, False, False, False,
#         False, False, False,  True, False, False, False, False, False])

# %%
def evaluate(model, data):
    model.eval()
    with torch.no_grad():
        pred = model(data.x, data.edge_index)

        # Convert logits to class labels
        pred_labels = pred[0].argmax(dim=1)

        correct = (pred_labels[data.test_mask] == data.y[data.test_mask]).sum()
        acc = int(correct) / int(data.test_mask.sum())
        print(f'Accuracy: {acc:.4f}')

# Example usage
evaluate(model, pyg_data)
# Out:
# Accuracy: 0.7966
