# %%
# Install required packages.
import os
import torch
os.environ['TORCH'] = torch.__version__
print(torch.__version__)

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q git+https://github.com/pyg-team/pytorch_geometric.git

# Helper function for visualization.
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

def visualize(h, color):
    z = TSNE(n_components=2).fit_transform(h.detach().cpu().numpy())

    plt.figure(figsize=(10,10))
    plt.xticks([])
    plt.yticks([])

    plt.scatter(z[:, 0], z[:, 1], s=70, c=color, cmap="Set2")
    plt.show()
# Out:
# 2.0.0+cu117

# %%
# Load the graph data from a file
import pickle

with open('output/graph_data.pickle', 'rb') as file:
    G = pickle.load(file)

# Print nodes with their embedding
for node, embedding in G.nodes(data=True):
    print(f"Node: {node}, embedding: {embedding}")
# Out:
# Node: org.jfree.chart.plot.pie, embedding: {'NumberOfEntities': 7.0, 'NumberOfClasses': 7.0, 'NumberOfInterface': 0.0, 'LOC': 1699.0, 'AC': 4.0, 'EC': 5.0, 'Abstractness': 0.143, 'Instability': 0.556, 'NormalizedDistances': 0.301, 'WMC': 447.0, 'is_god_component': 0}
# Node: org.jfree.data.gantt, embedding: {'NumberOfEntities': 6.0, 'NumberOfClasses': 5.0, 'NumberOfInterface': 1.0, 'LOC': 723.0, 'AC': 1.0, 'EC': 6.0, 'Abstractness': 0.167, 'Instability': 0.857, 'NormalizedDistances': 0.024, 'WMC': 222.0, 'is_god_component': 0}
# Node: org.jfree.chart.internal, embedding: {'NumberOfEntities': 8.0, 'NumberOfClasses': 8.0, 'NumberOfInterface': 0.0, 'LOC': 898.0, 'AC': 264.0, 'EC': 2.0, 'Abstractness': 0.0, 'Instability': 0.008, 'NormalizedDistances': 0.992, 'WMC': 257.0, 'is_god_component': 0}
# Node: org.jfree.chart.util, embedding: {'NumberOfEntities': 10.0, 'NumberOfClasses': 8.0, 'NumberOfInterface': 2.0, 'LOC': 558.0, 'AC': 27.0, 'EC': 4.0, 'Abstractness': 0.2, 'Instability': 0.129, 'NormalizedDistances': 0.671, 'WMC': 140.0, 'is_god_component': 0}
# Node: org.jfree.chart.date, embedding: {'NumberOfEntities': 3.0, 'NumberOfClasses': 2.0, 'NumberOfInterface': 1.0, 'LOC': 425.0, 'AC': 4.0, 'EC': 0.0, 'Abstractness': 0.667, 'Instability': 0.0, 'NormalizedDistances': 0.333, 'WMC': 157.0, 'is_god_component': 0}
# Node: org.jfree.chart.title, embedding: {'NumberOfEntities': 6.0, 'NumberOfClasses': 6.0, 'NumberOfInterface': 0.0, 'LOC': 753.0, 'AC': 11.0, 'EC': 6.0, 'Abstractness': 0.167, 'Instability': 0.353, 'NormalizedDistances': 0.48, 'WMC': 221.0, 'is_god_component': 0}
# Node: org.jfree.chart.entity, embedding: {'NumberOfEntities': 16.0, 'NumberOfClasses': 15.0, 'NumberOfInterface': 1.0, 'LOC': 673.0, 'AC': 64.0, 'EC': 13.0, 'Abstractness': 0.063, 'Instability': 0.169, 'NormalizedDistances': 0.768, 'WMC': 214.0, 'is_god_component': 0}
# Node: org.jfree.chart.renderer.category, embedding: {'NumberOfEntities': 25.0, 'NumberOfClasses': 23.0, 'NumberOfInterface': 2.0, 'LOC': 4906.0, 'AC': 4.0, 'EC': 23.0, 'Abstractness': 0.12, 'Instability': 0.852, 'NormalizedDistances': 0.028, 'WMC': 1328.0, 'is_god_component': 1}
# Node: org.jfree.data.io, embedding: {'NumberOfEntities': 1.0, 'NumberOfClasses': 1.0, 'NumberOfInterface': 0.0, 'LOC': 70.0, 'AC': 0.0, 'EC': 1.0, 'Abstractness': 0.0, 'Instability': 1.0, 'NormalizedDistances': 0.0, 'WMC': 16.0, 'is_god_component': 0}
# Node: org.jfree.data.statistics, embedding: {'NumberOfEntities': 18.0, 'NumberOfClasses': 14.0, 'NumberOfInterface': 4.0, 'LOC': 1959.0, 'AC': 9.0, 'EC': 14.0, 'Abstractness': 0.389, 'Instability': 0.609, 'NormalizedDistances': 0.002, 'WMC': 587.0, 'is_god_component': 1}
# Node: org.jfree.chart.event, embedding: {'NumberOfEntities': 18.0, 'NumberOfClasses': 10.0, 'NumberOfInterface': 8.0, 'LOC': 118.0, 'AC': 36.0, 'EC': 7.0, 'Abstractness': 0.444, 'Instability': 0.163, 'NormalizedDistances': 0.393, 'WMC': 36.0, 'is_god_component': 0}
# Node: org.jfree.chart.block, embedding: {'NumberOfEntities': 22.0, 'NumberOfClasses': 17.0, 'NumberOfInterface': 5.0, 'LOC': 1723.0, 'AC': 19.0, 'EC': 18.0, 'Abstractness': 0.227, 'Instability': 0.486, 'NormalizedDistances': 0.287, 'WMC': 485.0, 'is_god_component': 0}
# Node: org.jfree.data.json, embedding: {'NumberOfEntities': 1.0, 'NumberOfClasses': 1.0, 'NumberOfInterface': 0.0, 'LOC': 74.0, 'AC': 0.0, 'EC': 1.0, 'Abstractness': 0.0, 'Instability': 1.0, 'NormalizedDistances': 0.0, 'WMC': 16.0, 'is_god_component': 0}
# Node: org.jfree.chart.legend, embedding: {'NumberOfEntities': 8.0, 'NumberOfClasses': 7.0, 'NumberOfInterface': 1.0, 'LOC': 1191.0, 'AC': 38.0, 'EC': 6.0, 'Abstractness': 0.125, 'Instability': 0.136, 'NormalizedDistances': 0.739, 'WMC': 325.0, 'is_god_component': 0}
# Node: org.jfree.chart.axis, embedding: {'NumberOfEntities': 46.0, 'NumberOfClasses': 44.0, 'NumberOfInterface': 2.0, 'LOC': 7056.0, 'AC': 91.0, 'EC': 32.0, 'Abstractness': 0.152, 'Instability': 0.26, 'NormalizedDistances': 0.588, 'WMC': 1828.0, 'is_god_component': 1}
# Node: org.jfree.chart.labels, embedding: {'NumberOfEntities': 38.0, 'NumberOfClasses': 27.0, 'NumberOfInterface': 11.0, 'LOC': 1503.0, 'AC': 46.0, 'EC': 37.0, 'Abstractness': 0.316, 'Instability': 0.446, 'NormalizedDistances': 0.238, 'WMC': 402.0, 'is_god_component': 0}
# Node: org.jfree.chart.imagemap, embedding: {'NumberOfEntities': 7.0, 'NumberOfClasses': 5.0, 'NumberOfInterface': 2.0, 'LOC': 131.0, 'AC': 2.0, 'EC': 1.0, 'Abstractness': 0.286, 'Instability': 0.333, 'NormalizedDistances': 0.381, 'WMC': 35.0, 'is_god_component': 0}
# Node: org.jfree.chart.text.format, embedding: {'NumberOfEntities': 4.0, 'NumberOfClasses': 4.0, 'NumberOfInterface': 0.0, 'LOC': 298.0, 'AC': 0.0, 'EC': 2.0, 'Abstractness': 0.0, 'Instability': 1.0, 'NormalizedDistances': 0.0, 'WMC': 81.0, 'is_god_component': 0}
# Node: org.jfree.chart.encoders, embedding: {'NumberOfEntities': 6.0, 'NumberOfClasses': 4.0, 'NumberOfInterface': 2.0, 'LOC': 151.0, 'AC': 1.0, 'EC': 2.0, 'Abstractness': 0.333, 'Instability': 0.667, 'NormalizedDistances': 0.0, 'WMC': 38.0, 'is_god_component': 0}
# Node: org.jfree.chart.plot.flow, embedding: {'NumberOfEntities': 1.0, 'NumberOfClasses': 1.0, 'NumberOfInterface': 0.0, 'LOC': 331.0, 'AC': 0.0, 'EC': 1.0, 'Abstractness': 0.0, 'Instability': 1.0, 'NormalizedDistances': 0.0, 'WMC': 88.0, 'is_god_component': 0}
# Node: org.jfree.chart.annotations, embedding: {'NumberOfEntities': 20.0, 'NumberOfClasses': 16.0, 'NumberOfInterface': 4.0, 'LOC': 1929.0, 'AC': 6.0, 'EC': 20.0, 'Abstractness': 0.3, 'Instability': 0.769, 'NormalizedDistances': 0.069, 'WMC': 457.0, 'is_god_component': 0}
# Node: org.jfree.chart.plot, embedding: {'NumberOfEntities': 36.0, 'NumberOfClasses': 32.0, 'NumberOfInterface': 4.0, 'LOC': 9460.0, 'AC': 107.0, 'EC': 24.0, 'Abstractness': 0.167, 'Instability': 0.183, 'NormalizedDistances': 0.65, 'WMC': 2922.0, 'is_god_component': 1}
# Node: org.jfree.chart.api, embedding: {'NumberOfEntities': 14.0, 'NumberOfClasses': 13.0, 'NumberOfInterface': 1.0, 'LOC': 418.0, 'AC': 215.0, 'EC': 3.0, 'Abstractness': 0.071, 'Instability': 0.014, 'NormalizedDistances': 0.915, 'WMC': 105.0, 'is_god_component': 0}
# Node: org.jfree.data, embedding: {'NumberOfEntities': 27.0, 'NumberOfClasses': 18.0, 'NumberOfInterface': 9.0, 'LOC': 1406.0, 'AC': 117.0, 'EC': 14.0, 'Abstractness': 0.37, 'Instability': 0.107, 'NormalizedDistances': 0.523, 'WMC': 472.0, 'is_god_component': 0}
# Node: org.jfree.data.time.ohlc, embedding: {'NumberOfEntities': 4.0, 'NumberOfClasses': 4.0, 'NumberOfInterface': 0.0, 'LOC': 231.0, 'AC': 0.0, 'EC': 4.0, 'Abstractness': 0.0, 'Instability': 1.0, 'NormalizedDistances': 0.0, 'WMC': 73.0, 'is_god_component': 0}
# Node: org.jfree.chart.urls, embedding: {'NumberOfEntities': 12.0, 'NumberOfClasses': 8.0, 'NumberOfInterface': 4.0, 'LOC': 413.0, 'AC': 19.0, 'EC': 12.0, 'Abstractness': 0.333, 'Instability': 0.387, 'NormalizedDistances': 0.28, 'WMC': 130.0, 'is_god_component': 0}
# Node: org.jfree.data.category, embedding: {'NumberOfEntities': 7.0, 'NumberOfClasses': 4.0, 'NumberOfInterface': 3.0, 'LOC': 605.0, 'AC': 52.0, 'EC': 6.0, 'Abstractness': 0.429, 'Instability': 0.103, 'NormalizedDistances': 0.468, 'WMC': 209.0, 'is_god_component': 0}
# Node: org.jfree.data.function, embedding: {'NumberOfEntities': 5.0, 'NumberOfClasses': 4.0, 'NumberOfInterface': 1.0, 'LOC': 120.0, 'AC': 1.0, 'EC': 4.0, 'Abstractness': 0.2, 'Instability': 0.8, 'NormalizedDistances': 0.0, 'WMC': 37.0, 'is_god_component': 0}
# Node: org.jfree.chart.renderer.xy, embedding: {'NumberOfEntities': 45.0, 'NumberOfClasses': 43.0, 'NumberOfInterface': 2.0, 'LOC': 7141.0, 'AC': 6.0, 'EC': 34.0, 'Abstractness': 0.067, 'Instability': 0.85, 'NormalizedDistances': 0.083, 'WMC': 1908.0, 'is_god_component': 1}
# Node: org.jfree.data.flow, embedding: {'NumberOfEntities': 5.0, 'NumberOfClasses': 4.0, 'NumberOfInterface': 1.0, 'LOC': 280.0, 'AC': 5.0, 'EC': 5.0, 'Abstractness': 0.2, 'Instability': 0.5, 'NormalizedDistances': 0.3, 'WMC': 104.0, 'is_god_component': 0}
# Node: org.jfree.chart.plot.dial, embedding: {'NumberOfEntities': 18.0, 'NumberOfClasses': 14.0, 'NumberOfInterface': 4.0, 'LOC': 1766.0, 'AC': 0.0, 'EC': 12.0, 'Abstractness': 0.333, 'Instability': 1.0, 'NormalizedDistances': 0.333, 'WMC': 464.0, 'is_god_component': 0}
# Node: org.jfree.chart.text, embedding: {'NumberOfEntities': 10.0, 'NumberOfClasses': 9.0, 'NumberOfInterface': 1.0, 'LOC': 818.0, 'AC': 54.0, 'EC': 5.0, 'Abstractness': 0.1, 'Instability': 0.085, 'NormalizedDistances': 0.815, 'WMC': 240.0, 'is_god_component': 0}
# Node: org.jfree.chart.swing, embedding: {'NumberOfEntities': 16.0, 'NumberOfClasses': 12.0, 'NumberOfInterface': 4.0, 'LOC': 1918.0, 'AC': 0.0, 'EC': 8.0, 'Abstractness': 0.25, 'Instability': 1.0, 'NormalizedDistances': 0.25, 'WMC': 506.0, 'is_god_component': 1}
# Node: org.jfree.data.time, embedding: {'NumberOfEntities': 27.0, 'NumberOfClasses': 26.0, 'NumberOfInterface': 1.0, 'LOC': 3390.0, 'AC': 10.0, 'EC': 20.0, 'Abstractness': 0.074, 'Instability': 0.667, 'NormalizedDistances': 0.259, 'WMC': 999.0, 'is_god_component': 1}
# Node: org.jfree.chart, embedding: {'NumberOfEntities': 13.0, 'NumberOfClasses': 9.0, 'NumberOfInterface': 4.0, 'LOC': 2441.0, 'AC': 64.0, 'EC': 5.0, 'Abstractness': 0.462, 'Instability': 0.072, 'NormalizedDistances': 0.466, 'WMC': 576.0, 'is_god_component': 1}
# Node: org.jfree.chart.swing.editor, embedding: {'NumberOfEntities': 18.0, 'NumberOfClasses': 16.0, 'NumberOfInterface': 2.0, 'LOC': 1360.0, 'AC': 1.0, 'EC': 12.0, 'Abstractness': 0.111, 'Instability': 0.923, 'NormalizedDistances': 0.034, 'WMC': 277.0, 'is_god_component': 0}
# Node: org.jfree.chart.plot.compass, embedding: {'NumberOfEntities': 11.0, 'NumberOfClasses': 11.0, 'NumberOfInterface': 0.0, 'LOC': 833.0, 'AC': 0.0, 'EC': 3.0, 'Abstractness': 0.091, 'Instability': 1.0, 'NormalizedDistances': 0.091, 'WMC': 230.0, 'is_god_component': 0}
# Node: org.jfree.data.json.impl, embedding: {'NumberOfEntities': 5.0, 'NumberOfClasses': 3.0, 'NumberOfInterface': 2.0, 'LOC': 228.0, 'AC': 1.0, 'EC': 0.0, 'Abstractness': 0.4, 'Instability': 0.0, 'NormalizedDistances': 0.6, 'WMC': 77.0, 'is_god_component': 0}
# Node: org.jfree.data.xy, embedding: {'NumberOfEntities': 52.0, 'NumberOfClasses': 40.0, 'NumberOfInterface': 12.0, 'LOC': 3072.0, 'AC': 76.0, 'EC': 34.0, 'Abstractness': 0.288, 'Instability': 0.309, 'NormalizedDistances': 0.403, 'WMC': 980.0, 'is_god_component': 1}
# Node: org.jfree.data.general, embedding: {'NumberOfEntities': 25.0, 'NumberOfClasses': 15.0, 'NumberOfInterface': 10.0, 'LOC': 1614.0, 'AC': 86.0, 'EC': 13.0, 'Abstractness': 0.56, 'Instability': 0.131, 'NormalizedDistances': 0.309, 'WMC': 540.0, 'is_god_component': 1}
# Node: org.jfree.data.xml, embedding: {'NumberOfEntities': 9.0, 'NumberOfClasses': 8.0, 'NumberOfInterface': 1.0, 'LOC': 300.0, 'AC': 0.0, 'EC': 8.0, 'Abstractness': 0.111, 'Instability': 1.0, 'NormalizedDistances': 0.111, 'WMC': 78.0, 'is_god_component': 0}
# Node: org.jfree.chart.renderer, embedding: {'NumberOfEntities': 15.0, 'NumberOfClasses': 13.0, 'NumberOfInterface': 2.0, 'LOC': 1862.0, 'AC': 56.0, 'EC': 8.0, 'Abstractness': 0.2, 'Instability': 0.125, 'NormalizedDistances': 0.675, 'WMC': 609.0, 'is_god_component': 1}

# %%
import torch
from torch_geometric.data import Data

def networkx_to_pyg_data(graph):
    node_features_list = []
    labels = []
    node_mapping = {}
    node_index = 0

    for node, node_data in graph.nodes(data=True):
        node_mapping[node] = node_index
        features = [node_data['NumberOfEntities'], 
                    node_data['NumberOfClasses'], 
                    node_data['NumberOfInterface'], 
                    node_data['LOC'],
                    node_data['AC'],
                    node_data['EC'],
                    node_data['Abstractness'],
                    node_data['Instability'],
                    node_data['NormalizedDistances'],
                    node_data['WMC']]
        node_features_list.append(features)
        labels.append(node_data['is_god_component'])
        node_index += 1

    edge_index = []
    for source, target in graph.edges():
        edge_index.append([node_mapping[source], node_mapping[target]])
    
    edge_index = torch.tensor(edge_index, dtype=torch.long).t().contiguous()
    x = torch.tensor(node_features_list, dtype=torch.float)
    y = torch.tensor(labels, dtype=torch.long)

    return Data(x=x, edge_index=edge_index, y=y)

pyg_data = networkx_to_pyg_data(G)

# %%
def add_num_classes_to_pyg_data(data):
    num_classes = data.y.unique().size(0)
    data.num_classes = num_classes
    
add_num_classes_to_pyg_data(pyg_data)

print(f"Number of classes: {pyg_data.num_classes}")
# Out:
# Number of classes: 2

# %%
print(f'Dataset: {pyg_data}:')
print('======================')
print(f'Number of graphs: {len(pyg_data)}')
print(f'Number of features: {pyg_data.num_features}')
print(f'Number of classes: {pyg_data.num_classes}')
print(f'Number of nodes: {pyg_data.num_nodes}')
print(f'Number of edges: {pyg_data.num_edges}')
print(f'Average node degree: {pyg_data.num_edges / pyg_data.num_nodes:.2f}')
print(f'Has isolated nodes: {pyg_data.has_isolated_nodes()}')
print(f'Has self-loops: {pyg_data.has_self_loops()}')
print(f'Is undirected: {pyg_data.is_undirected()}')
# Out:
# Dataset: Data(x=[42, 10], edge_index=[2, 852], y=[42], num_classes=2):
# ======================
# Number of graphs: 4
# Number of features: 10
# Number of classes: 2
# Number of nodes: 42
# Number of edges: 852
# Average node degree: 20.29
# Has isolated nodes: False
# Has self-loops: False
# Is undirected: False

# %%
def save_pyg_dataset(dataset, file_path):
    torch.save(dataset, file_path)

# Assuming 'pyg_dataset' is the dataset you want to save
output_file_path = 'output/pyg_dataset.pt'
save_pyg_dataset(pyg_data, output_file_path)

# %%
import networkx as nx
from torch_geometric.utils import to_networkx

def visualize_graph(G, color):
    plt.figure(figsize=(7,7))
    plt.xticks([])
    plt.yticks([])
    nx.draw_networkx(G, pos=nx.spring_layout(G, seed=42), with_labels=False,
                     node_color=color, cmap="Set2")
    plt.show()

G = to_networkx(pyg_data, to_undirected=True)
visualize_graph(G, color=pyg_data.y)

# %%
import torch
from torch.nn import Linear
from torch_geometric.nn import GCNConv

class GCN(torch.nn.Module):
    def __init__(self):
        super().__init__()
        torch.manual_seed(1234)
        self.conv1 = GCNConv(pyg_data.num_features, 4)
        self.conv2 = GCNConv(4, 4)
        self.conv3 = GCNConv(4, 2)
        self.classifier = Linear(2, pyg_data.num_classes)

    def forward(self, x, edge_index):
        h = self.conv1(x, edge_index)
        h = h.tanh()
        h = self.conv2(h, edge_index)
        h = h.tanh()
        h = self.conv3(h, edge_index)
        h = h.tanh()  # Final GNN embedding space.
        
        # Apply a final (linear) classifier.
        out = self.classifier(h)

        return out, h

model = GCN()
print(model)
# Out:
# GCN(
#   (conv1): GCNConv(10, 4)
#   (conv2): GCNConv(4, 4)
#   (conv3): GCNConv(4, 2)
#   (classifier): Linear(in_features=2, out_features=2, bias=True)
# )

# %%
model = GCN()

_, h = model(pyg_data.x, pyg_data.edge_index)
print(f'Embedding shape: {list(h.shape)}')

def visualize_embedding(h, color, epoch=None, loss=None):
    plt.figure(figsize=(7,7))
    plt.xticks([])
    plt.yticks([])
    h = h.detach().cpu().numpy()
    plt.scatter(h[:, 0], h[:, 1], s=140, c=color, cmap="Set2")
    if epoch is not None and loss is not None:
        plt.xlabel(f'Epoch: {epoch}, Loss: {loss.item():.4f}', fontsize=16)
    plt.show()

visualize_embedding(h, color=pyg_data.y)
# Out:
# Embedding shape: [42, 2]

# %%
import random

def add_train_mask_to_pyg_data(data, train_ratio=0.8):
    num_nodes = data.num_nodes
    num_train_nodes = int(train_ratio * num_nodes)

    # Generate a list of True and False values with the specified ratio
    mask_values = [True] * num_train_nodes + [False] * (num_nodes - num_train_nodes)

    # Randomly shuffle the mask values
    random.shuffle(mask_values)

    # Convert the mask_values list to a boolean tensor and assign it to the Data object
    data.train_mask = torch.tensor(mask_values, dtype=torch.bool)

# Example usage
add_train_mask_to_pyg_data(pyg_data, train_ratio=0.8)

print(f"Train mask: {pyg_data.train_mask}")
# Out:
# Train mask: tensor([False, False,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True, False,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True, False,  True,  True,
#         False,  True, False, False,  True,  True, False,  True,  True, False,
#          True,  True])

# %%
import time
from IPython.display import Javascript  # Restrict height of output cell.
display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 430})'''))

model = GCN()
criterion = torch.nn.CrossEntropyLoss()  # Define loss criterion.
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)  # Define optimizer.

def train(data):
    optimizer.zero_grad()  # Clear gradients.
    out, h = model(data.x, data.edge_index)  # Perform a single forward pass.
    loss = criterion(out[data.train_mask], data.y[data.train_mask])  # Compute the loss solely based on the training nodes.
    loss.backward()  # Derive gradients.
    optimizer.step()  # Update parameters based on gradients.
    return loss, h

for epoch in range(1001):
    loss, h = train(pyg_data)
    if epoch % 100 == 0:
        visualize_embedding(h, color=pyg_data.y, epoch=epoch, loss=loss)
        time.sleep(0.3)

# %%
def add_test_mask_to_pyg_data(data):
    # If the train_mask is not set, raise an exception
    if not hasattr(data, 'train_mask'):
        raise ValueError("Please add a train_mask to the Data object first.")
    
    # Create a test mask as the complement of the train mask
    data.test_mask = ~data.train_mask

add_test_mask_to_pyg_data(pyg_data)

print(f"Test mask: {pyg_data.test_mask}")
# Out:
# Test mask: tensor([ True,  True, False, False, False, False, False, False, False, False,
#         False, False, False, False,  True, False, False, False, False, False,
#         False, False, False, False, False, False, False,  True, False, False,
#          True, False,  True,  True, False, False,  True, False, False,  True,
#         False, False])

# %%
def evaluate(model, data):
    model.eval()
    with torch.no_grad():
        pred = model(data.x, data.edge_index)

        # Convert logits to class labels
        pred_labels = pred[0].argmax(dim=1)

        correct = (pred_labels[data.test_mask] == data.y[data.test_mask]).sum()
        acc = int(correct) / int(data.test_mask.sum())
        print(f'Accuracy: {acc:.4f}')

# Example usage
evaluate(model, pyg_data)
# Out:
# Accuracy: 0.4444
